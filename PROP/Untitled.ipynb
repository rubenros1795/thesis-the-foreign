# %%
import re, os, glob, pandas as pd
import editdistance
import sys
import dask.dataframe as dd

# %%
os.chdir("C://Users//Ruben//Documents//GitHub//TheForeign//SCC//output-data")

# %%
df = pd.read_csv("unigrams_wereld.csv")

# %%
# Out:
#                           ngram  1815  1816  1817  1818  1819  1820  1821  \
# 1025                     wereld   457   251   233   232   216   225   297
# 1026                   wereld 1     0     0     0     0     0     0     0
# 1027                 wereld aan     0     0     0     0     0     0     0
# 1028              wereld achter     0     0     0     0     0     0     0
# 1029                  wereld af     0     0     0     0     0     0     0
# 1030            wereld afdwingt     0     0     0     0     0     0     0
# 1031          wereld afgesloten     0     0     0     0     0     0     0
# 1032                  wereld al     0     0     0     0     0     0     0
# 1033              wereld alleen     0     0     0     0     0     0     0
# 1034                 wereld als     0     0     0     0     0     0     0
# 1035          wereld antwoordde     0     0     0     0     0     0     0
# 1036                 wereld bad     0     0     0     0     0     0     0
# ...

# %%
df = df[df.ngram.str.split().str.len() == 1]
df = df[df.ngram.str[0:4] == "were"]
df = df.reset_index(drop=True)

# %%
df.to_csv("unigrams_wereld_clean.csv", index=False)
