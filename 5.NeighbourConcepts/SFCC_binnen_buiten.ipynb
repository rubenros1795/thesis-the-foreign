# %%
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import glob
import os
from os import path
import string
import numpy
import re
from __future__ import absolute_import, division, print_function
import pandas as pd
import multiprocessing
import gensim
import random
from tqdm import tqdm
import pandas as pd
from gensim.models import KeyedVectors
from numpy import array
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
os.chdir('C://Users//Ruben//Documents//Scriptie//Data//kwic_dfs')
# Out:
# ['binnenlandsche_x_en_buitenlandsche_y.csv', 'binnen_en_buitenlandsche_x.csv']

# %%
os.chdir('C://Users//Ruben//Documents//GitHub//TheForeign//SCC//output-data')
model = KeyedVectors.load_word2vec_format('model-whole.bin', binary = True)

# %%
os.chdir('C://Users//Ruben//Documents//Scriptie//Data//kwic_dfs')
df = pd.read_csv('binnenlandsche_x_en_buitenlandsche_y.csv')

# %%
dfa = pd.DataFrame(df.p.str.split(' ').tolist(), columns = ['w1','w2','w3','w4','w5'])
dfa['total'] = df.p
dfa['year'] = df['year']
dfa = dfa[dfa.w3 == "en"]
dfa = dfa.reset_index(drop=True)
dictr = dict()
for c in range(0,94):
    name = dfa.w2[c] + "_" + dfa.w5[c]
    
    if dfa.w2[c] in list(model.vocab.keys()) and dfa.w5[c] in list(model.vocab.keys()):
    
        sim = model.similarity(dfa.w2[c], dfa.w5[c])
        dictr.update({name:sim})
[k for k,v in dictr.items() if v > 0.7]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# ['zaken_zaken',
#  'verkoopers_koopers',
#  'gedistilleerd_gedistilleerd',
#  'zaken_aangelegenheden',
#  'zakon_zaken']

# %%
Counter(list(dfa.total))
# Out:
# Counter({'binnenlandsche comsnmiie en buitenlandsche commercie': 1,
#          'binnenlandschen handel en buitenlandsche expeditien': 1,
#          'binnenlandsche kantonsregeringen en buitenlandsche hoven': 1,
#          'binnenlandsche 1445 en buitenlandsche 8735': 2,
#          'binnenlandsche hinderpalen en buitenlandsche gevaren': 1,
#          'binnenlandsche rust en buitenlandsche veiligheid': 1,
#          'binnenlandsche koloniale en buitenlandsche nieuwstijdingen': 1,
#          'binnenlandsche omwentelingen en buitenlandsche tusschenkomsten': 1,
#          'binnenlandsche zaken en buitenlandsche zaken': 22,
#          'binnenlandsche tyrannie en buitenlandsche interventie': 1,
#          'binnenlandsche twiste en buitenlandsche kuiperijen': 1,
#          'binnenlandsche vrede en buitenlandsche sterkte': 1,
#          'binnenlandsche onlusten en buitenlandsche gewapende': 2,
#          'binnenlandsche verkoopers en buitenlandsche koopers': 1,
# ...

# %%
os.chdir('C://Users//Ruben//Documents//Scriptie//Data//kwic_dfs')
df = pd.read_csv('binnen_en_buitenlandsche_x.csv')

# %%
dfa = pd.DataFrame(df.p.str.split(' ').tolist(), columns = ['w1','w2','w3','w4'])
dfa['year'] = df['year']
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-55-bba4e573f17f> in <module>()
# ----> 1 dfa = pd.DataFrame(df.p.str.split(' ').tolist(), columns = ['w1','w2','w3','w4'])
#       2 dfa['year'] = df['year']
#       3 dfa['total'] = df.p
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7432     if isinstance(data[0], (list, tuple)):
# ...

# %%
dfa = dfa[dfa.w2 == "en"]
dfa = dfa.reset_index(drop=True)

# %%
from collections import Counter

Counter(list(dfa.w4))
# Out:
# Counter({'geleerde': 68,
#          'zaken': 818,
#          'vertier': 2,
#          'vrede': 12,
#          'tijdfehriften': 1,
#          'couranten': 39,
#          'zeep': 2,
#          'fabrieken': 37,
#          'tijdschriften': 117,
#          'vaartuigen': 7,
#          'handel': 26,
#          'journalen': 2,
#          'dagbladen': 145,
#          'producten': 7,
#          'schepen': 6,
#          'rust': 33,
#          'tyd—': 1,
#          'beweging': 1,
#          'vijanden': 133,
#          'maatsch': 1,
#          'ministers': 3,
#          'onaf': 1,
#          'tijdfehrifton': 1,
#          'vyanden': 4,
#          'wijn': 3,
#          'magt': 1,
#          'geleerden': 114,
#          'politiek': 458,
#          'scheetvaart': 1,
#          'aangelegenheid': 1,
#          'obligatiën': 4,
#          'betrekkingen': 39,
#          'tijjsclirifteh': 1,
#          'fondsen': 257,
#          'boekwerken': 5,
#          'fabrijken': 2,
#          'passen': 4,
# ...

# %%
dfa
# Out:
#                  w1                 w2  w3              w4               w5  \
# 0    binnenlandsche          comsnmiie  en  buitenlandsche        commercie
# 1   binnenlandschen             handel  en  buitenlandsche       expeditien
# 2    binnenlandsche  kantonsregeringen  en  buitenlandsche            hoven
# 3    binnenlandsche               1445  en  buitenlandsche             8735
# 4    binnenlandsche               1445  en  buitenlandsche             8735
# 5    binnenlandsche        hinderpalen  en  buitenlandsche          gevaren
# 6    binnenlandsche               rust  en  buitenlandsche       veiligheid
# 7    binnenlandsche          koloniale  en  buitenlandsche  nieuwstijdingen
# 8    binnenlandsche      omwentelingen  en  buitenlandsche  tusschenkomsten
# 9    binnenlandsche              zaken  en  buitenlandsche            zaken
# 10   binnenlandsche           tyrannie  en  buitenlandsche      interventie
# ...
