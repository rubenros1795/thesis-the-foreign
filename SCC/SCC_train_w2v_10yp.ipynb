# %%
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import glob
import os
from os import path
import string
import numpy
import re
from __future__ import absolute_import, division, print_function
import pandas as pd
import multiprocessing
import gensim
import random
from tqdm import tqdm
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
def file_len(fname):
    with open(fname, encoding = 'utf-8') as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %%
os.chdir("D://Scriptie//Data//lines//cleaned")
all_txt = glob.glob('*.txt')

# %%
for start_year in list(range(1815,1915,10)):
    list_txt_range = [t for t in all_txt if int(t[0:4]) >= start_year and int(t[0:4]) < start_year + 10]
    
    # Get Size of Range
    range_size = 0
    numb_lines = 0
    
    for txt in list_txt_range:
        statinfo = os.stat(txt)
        range_size += int(statinfo.st_size)
        numb_lines += file_len(txt)
    
    range_size = round(range_size/ 1000000)
        
    sample_size = 601
    
    if range_size > 600:
        tot_lines_samp = round(sample_size * numb_lines / range_size)
        print('an average of ' + str(tot_lines_samp) + ' lines a file is going to be imported in period ' + str(start_year))
        
        lines_period = list()
        
        for txt in list_txt_range:
            with open(txt, encoding = 'utf-8') as f:
                content = f.read().splitlines()
                
                if len(content) <= round(tot_lines_samp / 10):
                    for line in content:
                        lines_period.append(line)
                
                if len(content) > round(tot_lines_samp / 10):
                    content = random.sample(content, round(tot_lines_samp / 10))
                    for line in content:
                        lines_period.append(line)
        
        with open('period_sample_' + str(start_year) + '.txt', 'w', encoding = 'utf-8') as file:
            for item in lines_period:
                    file.write("%s\n" % item)
                    
        print('period written to disk, on to the next')
    
    else:
        print('period is small enough')
        lines_period = list()
        
        for txt in list_txt_range:
            with open(txt, encoding = 'utf-8') as f:
                content = f.readlines()
                print(str(len(content)) + ' lines opened from: ' + txt)
                for line in content:
                        lines_period.append(line)
        
        with open('period_sample_' + str(start_year) + '.txt', 'w', encoding = 'utf-8') as file:
            for item in lines_period:
                    file.write("%s\n" % item)
        print('period written to disk, on to the next')
# Out:
# period is small enough
# 22988 lines opened from: 1815_cleaned.txt
# 22024 lines opened from: 1816_cleaned.txt
# 23146 lines opened from: 1817_cleaned.txt
# 24486 lines opened from: 1818_cleaned.txt
# 20386 lines opened from: 1819_cleaned.txt
# 23180 lines opened from: 1820_cleaned.txt
# 23722 lines opened from: 1821_cleaned.txt
# 22950 lines opened from: 1822_cleaned.txt
# 23532 lines opened from: 1823_cleaned.txt
# 24242 lines opened from: 1824_cleaned.txt
# period written to disk, on to the next
# period is small enough
# 23510 lines opened from: 1825_cleaned.txt
# 24066 lines opened from: 1826_cleaned.txt
# 22404 lines opened from: 1827_cleaned.txt
# 23650 lines opened from: 1828_cleaned.txt
# 25424 lines opened from: 1829_cleaned.txt
# 28104 lines opened from: 1830_cleaned.txt
# 31080 lines opened from: 1831_cleaned.txt
# 35238 lines opened from: 1832_cleaned.txt
# 33646 lines opened from: 1833_cleaned.txt
# 37462 lines opened from: 1834_cleaned.txt
# period written to disk, on to the next
# an average of 349274 lines a file is going to be imported in period 1835
# period written to disk, on to the next
# an average of 426798 lines a file is going to be imported in period 1845
# period written to disk, on to the next
# an average of 461053 lines a file is going to be imported in period 1855
# period written to disk, on to the next
# an average of 413357 lines a file is going to be imported in period 1865
# period written to disk, on to the next
# an average of 441016 lines a file is going to be imported in period 1875
# period written to disk, on to the next
# an average of 426403 lines a file is going to be imported in period 1885
# period written to disk, on to the next
# an average of 427667 lines a file is going to be imported in period 1895
# period written to disk, on to the next
# an average of 505962 lines a file is going to be imported in period 1905
# period written to disk, on to the next

# %%
list_sample_txt = glob.glob('*.txt')
list_sample_txt = [f for f in list_sample_txt if f[0:4] == 'peri']
list_sample_txt
# Out:
# ['period_sample_1815.txt',
#  'period_sample_1825.txt',
#  'period_sample_1835.txt',
#  'period_sample_1845.txt',
#  'period_sample_1855.txt',
#  'period_sample_1865.txt',
#  'period_sample_1875.txt',
#  'period_sample_1885.txt',
#  'period_sample_1895.txt',
#  'period_sample_1905.txt']

# %%
def Txt_Lines(txt):
    with open(txt, encoding = 'utf-8') as f:
            content = f.read().split('\n')
    
    lines = list()
    
    for line in content:
        tmp = line.split(' ')
        lines.append(tmp)
    
    return lines

# %%
count = 0

for txt in list_sample_txt:
    if count == 0:
        count += 1
        sentences = Txt_Lines(txt)
        model = gensim.models.Word2Vec(sentences, min_count=100, workers=6)
        model.save(str(txt[14:18])+"_model.w2v")
        print("Model saved, on to the next\n")
        
    if count > 0:
        sentences = Txt_Lines(txt)
        model.build_vocab(sentences, update=True)
        model.train(sentences, total_examples = model.corpus_count, start_alpha = model.alpha, end_alpha = model.min_alpha, epochs = model.iter)
        model.save(str(txt[14:18])+"_model.w2v")
        print("Model saved, on to the next\n")
# Out:
# Model saved, on to the next
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next
#
# Model saved, on to the next

# %%
model = Word2Vec.load('1895_static_model.bin')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-6-a3395b3306c8> in <module>()
# ----> 1 model = Word2Vec.load('1895_static_model.bin')
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\word2vec.py in load(cls, *args, **kwargs)
#    1310         """
#    1311         try:
# -> 1312             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1313
#    1314             # for backward compatibility for `max_final_vocab` feature
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in load(cls, *args, **kwargs)
#    1242
#    1243         """
# -> 1244         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1245         if not hasattr(model, 'ns_exponent'):
#    1246             model.ns_exponent = 0.75
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     601
#     602         """
# --> 603         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     604
#     605     def save(self, fname_or_handle, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py in load(cls, fname, mmap)
#     420         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     421
# --> 422         obj = unpickle(fname)
#     423         obj._load_specials(fname, mmap, compress, subname)
#     424         logger.info("loaded %s", fname)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py in unpickle(fname)
#    1359         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1360         if sys.version_info > (3, 0):
# -> 1361             return _pickle.load(f, encoding='latin1')
#    1362         else:
#    1363             return _pickle.loads(f.read())
#
# UnpicklingError: unpickling stack underflow

# %%
def getw(word, n):
    tmp = model.most_similar(word)[n][0]
    tmp = " " + tmp + " "
    return tmp

# %%
list_mod = glob.glob('*.w2v')

for i in list(range(1815,1906,10)):
    mfn = [m for m in list_mod if int(m[0:4]) == i]
    model = Word2Vec.load(mfn[0])
    word = 'buitenlandsche'
    #print(str(i) + ' ' + getw(word,0) + getw(word,1) + getw(word,2) + getw(word,3))
    print(str(model.similarity('moederland', 'vaderland')))# + " | " + str(model.similarity('binnenlandsche', 'vaderlandsche')))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.5114883
# 0.53946126
# 0.5609166
# 0.5714821
# 0.5344653
# 0.5383246
# 0.565197
# 0.61158526
# 0.57237357
# 0.59126824

# %%
getw('buitenland',2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'duitschland'

# %%
from sklearn.cluster import KMeans;
from sklearn.neighbors import KDTree;
Z = model.wv.syn0
def clustering_on_wordvecs(word_vectors, num_clusters):
    # Initalize a k-means object and use it to extract centroids
    kmeans_clustering = KMeans(n_clusters = num_clusters, init='k-means++');
    idx = kmeans_clustering.fit_predict(word_vectors);
    return kmeans_clustering.cluster_centers_, idx;
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
centers, clusters = clustering_on_wordvecs(Z, 100);
centroid_map = dict(zip(model.wv.index2word, clusters));

# %%
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt;
from itertools import cycle;

def get_top_words(index2word, k, centers, wordvecs):
    tree = KDTree(wordvecs);
#Closest points for each Cluster center is used to query the closest 20 points to it.
    closest_points = [tree.query(np.reshape(x, (1, -1)), k=k) for x in centers];
    closest_words_idxs = [x[1] for x in closest_points];
#Word Index is queried for each position in the above array, and added to a Dictionary.
    closest_words = {};
    for i in range(0, len(closest_words_idxs)):
        closest_words['Cluster #' + str(i)] = [index2word[j] for j in closest_words_idxs[i][0]]
#A DataFrame is generated from the dictionary.
    df = pd.DataFrame(closest_words);
    df.index = df.index+1
    return df

# %%
import numpy as np
top_words = get_top_words(model.wv.index2word, 5000, centers, Z);

# %%
top_words
# Out:
#                 Cluster #0     Cluster #1            Cluster #2  \
# 1               demokraten          ƒ2250                 éenen
# 2           ultraliberalen          ƒ2750           officieelen
# 3           konservatieven            flb                 eénen
# 4          regeringspartij            ƒ20                «lezen
# 5             middenpartij        varkena            officiëlen
# 6           intransigenten            f2l                 hareu
# 7               unionisten          ƒ2350            deuzelfden
# 8             geëxalteerde        slieren           gewichtigen
# 9     ultrarepublikeinsche         geilen                 cencn
# 10         onverzoenlijken           totf            moeilijken
# 11               radikalen            fbo                zijoen
# 12              royalisten          hoter                 eenon
# 13          republiekeinen            f7o                 ceneu
# 14            doctrinaires        sohapen           moeielijken
# 15               hofpartij          perkg            algemecnen
# 16            doctrinairen          votto               grooteu
# 17          priesterpartij            ƒ70                 dezon
# 18               exaltados        varkeus                hnnnen
# 19            heethoofdige       lammoren            denzellden
# 20      fortschrittspartij            ƒ60               woesten
# 21           ultraliberale       scharren                zjjnen
# 22              jacobijnen           ƒ29—         dagelijkschen
# 23      ultrarepublikeinen            fl6            kolossalen
# 24          reactionnairen          tette        onmiddellijken
# 25          orleanistische         tarbot               kloeken
# 26               klerikale            ƒb6              deftigen
# 27           reactionairen           ƒ095          wereldlijken
# 28               repealers    hokkelingen                natten
# 29         revolulionnaire        aanvoor          vrijwilligen
# 30           konservatieve          ƒ3350            plechtigen
# ...                    ...            ...                   ...
# 4971                 ƒ1975         rienks                 bakel
# 4972                  ƒsb—       gisteten                 speld
# 4973          pennenstrijd           zij„             lnschrijv
# 4974             titelblad          voora             schatkobl
# 4975                  153—       bijßethm                  1249
# 4976             milwankee       nieuwold                   ƒo—
# 4977          marnixstraat     heemskerck                  vega
# 4978         ministerschap            bv2              tenessee
# 4979         onschadelijke   bureaucratie              vereenig
# 4980                    öt        ooslenr              bureelen
# 4981                   jei          zqnde             boerenerf
# 4982                  2055        verdund                schoei
# 4983                   soh           jets                 10113
# 4984                geslna    kristelijke  antischoolwetverbond
# 4985          overwinnende            54£                   vjn
# 4986           wijtenhorst      vloeibare               pothuis
# 4987                  4540          14950           volbrachten
# 4988                  3430           oblb            gravcnhage
# 4989                    1d    ziekenfonds             lijkkleed
# 4990                   86£          gelag                  iele
# 4991                madiid          koffu                   2is
# 4992                 conti          18634            syndicaat4
# 4993               doodgeb     afstamming           circuleeren
# 4994              referent  rijtuigvereen               geklemd
# 4995                  5480           1397                kilian
# 4996        pittsburgwayne          lamme                  4113
# 4997               bovenop            kie                  2085
# 4998           winterkoren        damiate                  2740
# 4999                  enp2         liften                   stv
# 5000                 boyal         nimrod            maestricht
#
#            Cluster #3           Cluster #4         Cluster #5  \
# 1                5810             zaamslag           vergiste
# 2                5980            renswoude           schaamde
# 3                5360            nieuwveen            schaamt
# 4                6010            heenvliet           haastten
# 5               14750               wilnis            ontspon
# 6                5630               deurne             ergert
# 7                8575           middelstum         terugtrekt
# 8                5640             leersurn           bemoeide
# 9                4980            zuilichem    verontschuldigt
# 10               5790             gouderak             stoort
# 11               5560             koekange         bekommerde
# 12               5410           zevenhoven   verontschuldigde
# 13               6280           varsseveld            onttrok
# 14               8525          waddinxveen         overtuigde
# 15               5780            koudekerk            kleedde
# 16               6020            beusichem            bevinde
# 17               5930            opheusden            stoorde
# 18               5340        bleskensgraaf           verbaast
# 19               5960      mijnsheerenland          aansloten
# 20               6510          voorthuizen      uitstrekkende
# 21               6380            leimuiden           aantrekt
# 22               5310           lekkerkerk          terugtrok
# 23               5330           bunschoten           aansloot
# 24               6060           linschoten          refereert
# 25               6480            landsmeer            schikte
# 26               4860            jaarsveld           verveelt
# 27               5460           zwammerdam          overgeeft
# 28               5710             nunspeet         bezighoudt
# 29               5720               heumen            aantrok
# 30               6080              zulphen          verdringt
# ...               ...                  ...                ...
# 4971       waterhooge  brandbluschmiddelen              stein
# 4972         frankrqk              pelinck             onraad
# 4973             1355             gohouden               1287
# 4974            12503                 paai         optedragen
# 4975              bïj                1001»               9658
# 4976            nairn              vanvres               ƒ247
# 4977              2ip                  ubl          afgereden
# 4978             9300                 f600      handelsmerken
# 4979              13i                 2455           gespoeld
# 4980  scheepssoldijen                 zior             schoei
# 4981              zif                 179—        ministeriel
# 4982          iescaut              zeegras              satan
# 4983           fisher           koudekerke               rian
# 4984       oostersehe                  tom            gcheele
# 4985             adsp                  isg          springtij
# 4986         spwaand3                 181—               ƒ166
# 4987            tocli                nissa               eien
# 4988             ored               parfls                lud
# 4989         kruising                  npg               jan—
# 4990             truc          schrevenweg  credietinstelling
# 4991        onbezorgd               f10005               ƒll5
# 4992            mheer                 bekt             hobbon
# 4993              i4j          poerworedjo            rankine
# 4994             6575            tubbergen    toegangskaarten
# 4995            eoner                 laar               3480
# 4996               s7                 wetk            hob1000
# 4997         lijsters                 ▼oor          facsimile
# 4998        zorgeloos              marburg         hartsuiker
# 4999             7538                damak           packages
# 5000           twente           voordewind               f2lo
#
#                 Cluster #6     Cluster #7      Cluster #8        Cluster #9  \
# 1              grootvesier         «ebben          inglis        landscrona
# 2           bondspresident          woren        crawford             malmö
# 3              grootvisier        heblien        drummond           gesiena
# 4        ministerprezident          °rden          russel       stolpemunde
# 5           bondskanselier        «worden           paget          stutvoet
# 6                     czar         woidcn           harry           harling
# 7     regeringscommissaris        worclen       wellesley            wyburg
# 8           raadspresident        wordtin         bussell        rugenwalde
# 9                   gezaut          werde       pakington     frederikshald
# 10            internuncius         woideu        melville            madsen
# 11                  kouiug         woraen         lindsay              boye
# 12                 taïkoen         heiben       carnarvon           elsiena
# 13                    pans        worden—         stephen         esperance
# 14                diktator         hobbon          sandon         margretha
# 15           gevolmagligde           bedt          clarke           eefting
# 16      goeverneurgeneraal           eelt          harvey           colding
# 17            hofkanselier          heben    westmoreland            malmoe
# 18               fuadpacha          worlt           smilh              eiga
# 19                   tsaar            »yn       ashburton              ates
# 20         oorlogsminister          erden       churchill          immanuel
# 21            bewindhebber         hebbe»           frere        norrköping
# 22                  sullan         rebben        hobhouse             ystad
# 23                  keiier        ■worden          garnet          meinders
# 24               landdrost         htbben       shepstone         pettersen
# 25              exdictator          haeft            mayo            afiena
# 26                delegaat        avorden           greij            lenger
# 27           grootadmiraal           werl        anglesey            jessen
# 28            keizerkoning         heoben      northbrook           banting
# 29                 nuncius         worlen          cairns        osterisoer
# 30             ambasfadenr         worelt      palmcrston           janlina
# ...                    ...            ...             ...               ...
# 4971                   v»b      tabletten   hiertegenover            kondon
# 4972                  kaut    hardsteenen       afgemeten              6260
# 4973                 urdax     huisdieren          droomt             perkg
# 4974                   f27       bluschte        analaboe            certic
# 4975            atsjinezen         moedor        everarda                l5
# 4976                 11814         wijfje    tvendestrand          ooievaar
# 4977              eerlange           5330          hapert               bso
# 4978                   21n   cosmopolitan   duizendtallen               64f
# 4979                 bonny  aardappelmeel           «eden            tienen
# 4980            leerboeken           2447         gr00tb3              niks
# 4981                  2127          zélfs         hypohio               84g
# 4982                  3220           5960        holscher           bauditz
# 4983                   46£      vorsehung       haagensen           willing
# 4984            wereldstad   inkrimpingen        broertje               „la
# 4985               fongers         ensing         shlelds        potititlis
# 4986               januarq            «ai     kloppenburg  belastingplannen
# 4987              broertje           4810        donderen               ƒ76
# 4988                goheel           meil            asnd       gravenliage
# 4989                ivarin            ••«            7632           verboom
# 4990               vaudrey            io»          vonder           hensing
# 4991              schackel  telegrapheert            9916        deponeeren
# 4992                 lobau         lot100           12600           veldwyk
# 4993                  1673           rerk     goldschmidt             20860
# 4994     schoolgeldheffing           ƒ224           «erst               —89
# 4995               reuther    eriespwaand         fchrjnt              3318
# 4996                  8758             °j            zeus            gedom»
# 4997                 ƒ1185            iob            1663         ijsbergen
# 4998                  5210        obligte            6530              fisk
# 4999                  f193      besteller  onheilspellend        coöperatie
# 5000              walchren        bardoux           «1200           fauchey
#
#                  ...                    Cluster #90   Cluster #91  \
# 1                ...                    edelaardige          lijm
# 2                ...                     blijmoedig      lijnwaad
# 3                ...              vaderlandlievende      zwartsel
# 4                ...                      oprechten        kurken
# 5                ...                    liefdevolle     glycerine
# 6                ...                        liefste     houtskool
# 7                ...                     welgemeend    houtskolen
# 8                ...                      liefheeft         eiwit
# 9                ...                    burgerdeugd    kwikzilver
# 10               ...                         zalige        potjes
# 11               ...                         nobele    carbolzuur
# 12               ...                      weemoedig         borax
# 13               ...                     kinderlijk    chloorkalk
# 14               ...                onuitsprekelijk      ammoniak
# 15               ...                          gelnk      macaroni
# 16               ...               offervaardigheid       zetmeel
# 17               ...                    vertrouwend   guttapercha
# 18               ...                    uitverkoren  vogelnestjes
# 19               ...                      innemende         zuren
# 20               ...                     weemoedige      stijfsel
# 21               ...                   rechtschapen      stikstof
# 22               ...                        gegroet    vermicelli
# 23               ...                     almachtige       naalden
# 24               ...                     bezielende        pitten
# 25               ...                      bezieling      koolteer
# 26               ...                   edelmoedigen    caoutchouc
# 27               ...                         kranke     vloeibare
# 28               ...                     ridderlijk        naphta
# 29               ...                      vergeving      mostaard
# 30               ...                       verkwikt      schelpen
# ...              ...                            ...           ...
# 4971             ...                          votto           4s4
# 4972             ...                    staatsieven        vereul
# 4973             ...                    kolokotroni  mademoiselle
# 4974             ...                        toepast         71000
# 4975             ...                            —05      beatrice
# 4976             ...                    ontblooting       buiteul
# 4977             ...                          unita       leonore
# 4978             ...                           loh4          6060
# 4979             ...                         wonend         bosma
# 4980             ...                      rumeniërs         goldt
# 4981             ...                           —per   avanceerden
# 4982             ...                          18634         bovon
# 4983             ...                       nieuwtje         gesis
# 4984             ...                 reaktionnairen           zop
# 4985             ...                         panier          5690
# 4986             ...                          mowle        ensing
# 4987             ...                        frowein          tros
# 4988             ...                         «lezen         bukte
# 4989             ...                    expresident       rankine
# 4990             ...                           3618        beigen
# 4991             ...                        wanueer         11617
# 4992             ...                           4875         „4765
# 4993             ...                             v£          1099
# 4994             ...                     tegenwicht          2260
# 4995             ...                          13012   walehersche
# 4996             ...                          scads           kov
# 4997             ...                    toeschieten            2y
# 4998             ...                         teutem      reporter
# 4999             ...                           poor    amsteldijk
# 5000             ...                         vuurde      begroeid
#
#               Cluster #92            Cluster #93      Cluster #94  \
# 1             veldstukken          declaratoiren         golstein
# 2             compagnieën             quitantiën            royen
# 3           mitrailleuses  arrondissementsijkers           boxman
# 4          kanonneerboten            gegadingden            röell
# 5              balaillons            overboeking         verheyen
# 6          policieagenten           fchriftelijk      voorthuyzen
# 7                redouten              verlofpas         eijsinga
# 8             bersaglieri       aanslagbiljetten       wijnaendts
# 9                 pontons           marktmeester           heloma
# 10             gensdarmes                grossen          romunde
# 11                 gidsen       dividendbewijzen          hoevell
# 12            galeiboeven                   akle         groeninx
# 13          geblesseerden    inschrijvingsbiljet        kempenaar
# 14               pelotons        boedelscheiding        gollstein
# 15              douaniers            voorschreve     dijckmeester
# 16           achterladers            wijkmeester    donkercurtius
# 17             karabijnen                  visum        lijcklama
# 18                prauwen             befcheiden           kerens
# 19               divisiën              genummerd         costerus
# 20            bajonnetten         presentielijst      dyckmeester
# 21                 ulanen             doorhaling            roëll
# 22            atchineezen     medeonderteekening         schiffer
# 23                 spahis        gekwalificeerde         wijbenga
# 24         dwangarbeiders          naamteekening      corverhooft
# 25          vrachtschepen           catalogussen          dorsser
# 26             stoomboten              aanvrager          outeren
# 27        politiedienaren          fchriftelijke           weerts
# 28       legerafdeelingen           dwangbevelen          meylink
# 29         burgerwachters            valschelijk        goltslein
# 30             chassepots               borderel          sickesz
# ...                   ...                    ...              ...
# 4971        reorganizatie                   varl            18250
# 4972                 muri         vleeschhouwers        heidegger
# 4973            kerkplein                    i««             bint
# 4974                wjjzo            rottcourant               ï5
# 4975                 waat              oogonblik         liefmans
# 4976                  44i             nederlbank        viooltjes
# 4977          capucijners                   1229    gisterochtend
# 4978       geaffecteerden                   3480  gepensionneerde
# 4979               rhijns                   ißso              76£
# 4980                 7858                    elt             ijjn
# 4981             bekoopen                   109—       komkommers
# 4982             irekgeld                   1068            poste
# 4983              riisoer        baltischespoorw             sink
# 4984                  0w5                    87ï              goj
# 4985               sphynx              vertaalde  10guldenstukken
# 4986                sthbr          nieuwenhuyzen          lukkina
# 4987            onbezorgd                    «of           185152
# 4988       najaarszitting                stikken              °de
# 4989                elzen                  mheer             3713
# 4990  stoombaartberichten                  hodon        nieuwveen
# 4991          burgervader            gearredeerd         bandiera
# 4992         weiwaterpomp            kunstwaarde              41s
# 4993                 6240                   ƒ324             uilo
# 4994               badong            zoutzieders       discussies
# 4995             stikstof                    «ok           fabryk
# 4996                 1608                   206—          bruijns
# 4997        moskoukursika         geaffecteerden           windkr
# 4998           jaartallen            torravechia        probeeren
# 4999             augsbnrg              inleggers              sus
# 5000               droomt               lenaerlz        hesselaar
#
#                   Cluster #95            Cluster #96       Cluster #97  \
# 1                   diaconiën                  gratz     maandagmorgen
# 2                 behoefligen               chambery        verlrokken
# 3                zondagschool                 olmütz     vrijdagmorgen
# 4               werkinrigting                  brünn        arriveeren
# 5          schoolonderwijzers                 rheims     gisterochtend
# 6                   diaconien              innsbruck   zaterdagochtend
# 7                   diakoniën               stutgart       exprestrein
# 8                volksscholen                berljjn   donderdagmorgen
# 9              normaalscholen                 weencn    zaterdagmorgen
# 10           ziekenverpleging               wurzburg      zondagmiddag
# 11                 weeshuizen              stuttgard      voortgereisd
# 12                 instituten                 spiers     dinsdagmorgen
# 13              liefdezusters              frohsdorf     vrijdagmiddag
# 14         roomschkatholieken                  brunn    woensdagmiddag
# 15                    kwakers               besancon    woensdagmorgen
# 16                  rabbijnen                 weeneu  zaterdagnamiddag
# 17                   kindoren                marburg     zondagochtend
# 18                    idioten            wilhelmsbad   donderdagmiddag
# 19             schoolmeesters                  reims    zaterdagmiddag
# 20                 israeliten                  görtz    maandagochtend
# 21              staatsscholen                 colmar     maandagmiddag
# 22             protestantsehe                bergamo        overbracht
# 23                 seminariën                 wcenen           treport
# 24    krankzinnigengestichten                 weeven    zondagnamiddag
# 25                religieuzen               chambéry          dineeren
# 26            gemeentescholen                 pesaro       zondagnacht
# 27               meergegoeden                 castel    gisternamiddag
# 28                  armenhuis                   romo   hedenvoormiddag
# 29            landbouwscholen                treviso         tervueren
# 30                zuigelingen                 olmutz     dinsdagmiddag
# ...                       ...                    ...               ...
# 4971                 lucardie                   4113              9358
# 4972                    89000  godsdienstonderwijzer             inaar
# 4973              windrigting                trouwde               hl4
# 4974             charteristen         noordbrabanter           1835500
# 4975                normandie         academiegebouw              ella
# 4976                      p»r                   6778              1684
# 4977                       éi                 wesley        philippart
# 4978                    ieren               oploopen     totstandkomen
# 4979              bewerkingen                   153—              6313
# 4980                   187881                   8625           haagsch
# 4981                   tolaal                   f725        deakpartij
# 4982               oostenrpap                meijnni             musch
# 4983                    1867r                 clercx             bouds
# 4984                pietertje                    »42        moerkerken
# 4985                     5160               frangois          schultze
# 4986             mademoiselle                    ic3            connet
# 4987               oostenrnat                   2205           welligl
# 4988                    ruzie             abbenbroek               33a
# 4989                     5640             lokomotief        michaelsen
# 4990                    jblig                   jeen          scheurde
# 4991                    ebels                bouvier             14812
# 4992                      ƒ70                  kajit           spanjer
# 4993                 ophoogen         omnibusmaatsch              1581
# 4994                       ev                afstond             14834
# 4995                 lidmaten                  heres               43f
# 4996                     2340                   teal               „30
# 4997                   hapsal             atchinezen               63a
# 4998                   pietro                   9058  zegelafschaffing
# 4999                    veten                   3713      beetwortelen
# 5000           priesterpartij              hariingen       falkenstein
#
#                Cluster #98                 Cluster #99
# 1           wetsvoordracht
# 2                 rijkswet                 magistraten
# 3                wjjziging                bureaucratie
# 4       grondwetherziening        billitonmaatschappij
# 5           kieshervorming                        data
# 6           rentebelasting            belastingplannen
# 7          tabaksbelasting                    quaestio
# 8                 rentewet                   regeeiing
# 9                 qnaestie                  uitschland
# 10      regeringsvoordragt               uitverkorenen
# 11        vreemdelingenwet                 voreeniging
# 12                quaestio                    totnutoe
# 13       effectenbelasting                      lieren
# 14        klassenbelasting                 transvalere
# 15             pensioenwet          politiemaatregelen
# 16        rijksconstitutie                 religieuzen
# 17         suikerbelasting                        tech
# 18    regeringsvoorstellen              commissieleden
# 19          suikerregeling                         orn
# 20      grondwetswijziging                  adressante
# 21               rogeering           dierenbescherming
# 22           schutterijwet            belastingheffing
# 23              kanalenwet                    partjjen
# 24           wetswijziging                   leidingen
# 25           opportuniteit                  vivisectie
# 26         gemaalbelasting                    situatie
# 27              zondagswet               samensmelting
# 28         bondshervorming                         jis
# 29        kabinetsformatie              onbillijkheden
# 30          schuldregeling             postspaarbanken
# ...                    ...                         ...
# 4971                  tleu                  martelaars
# 4972             lithoijen                       11671
# 4973           grondzuilen                         33§
# 4974           daarslellen                         9s4
# 4975                   17a                 buitenshuis
# 4976                  f550                 alkmaarsche
# 4977                  9758                       16820
# 4978              gemerkte                         dua
# 4979                   hdb                        119—
# 4980                  955»                       14450
# 4981            voorworpen                   pijptabak
# 4982            lafaijette                       16790
# 4983             aanbidden                         r4j
# 4984             dodewaard                        ƒ154
# 4985                   f12                   miniatuur
# 4986           speelplaats                          iè
# 4987               wolbers                 clipperbrik
# 4988          buitenwereld                   italienne
# 4989                zuthem                        210—
# 4990                  3938                    weissenb
# 4991                  »wjj                        1958
# 4992              monrovia                         18s
# 4993            stafschool  locaalspoorwegmaatschappij
# 4994                  wden                    plaatfcn
# 4995           havendienst                heerewaarden
# 4996                pouyer                        124—
# 4997           vatikaansch                        2780
# 4998          konijnenburg                         aoj
# 4999                  5160                       taiwe
# 5000               duclerc                   samenhang
#
# [5000 rows x 100 columns]

# %%
def display_cloud(cluster_num, cmap):
    wc = WordCloud(background_color="black", max_words=2000, max_font_size=80, colormap=cmap);
    wordcloud = wc.generate(' '.join([word for word in top_words['Cluster #' + str(cluster_num).zfill(2)]]))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    
display_cloud(, "prism")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cluster #00'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2ef8b1e3deef> in <module>()
#       5     plt.axis("off")
#       6
# ----> 7 display_cloud(0, "prism")
#
# <ipython-input-20-2ef8b1e3deef> in display_cloud(cluster_num, cmap)
#       1 def display_cloud(cluster_num, cmap):
#       2     wc = WordCloud(background_color="black", max_words=2000, max_font_size=80, colormap=cmap);
# ----> 3     wordcloud = wc.generate(' '.join([word for word in top_words['Cluster #' + str(cluster_num).zfill(2)]]))
#       4     plt.imshow(wordcloud, interpolation='bilinear')
#       5     plt.axis("off")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cluster #00'

# %%
model.most_similar('buitenwereld')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('buitenlucht', 0.5771310329437256),
#  ('wachtkamers', 0.5319221019744873),
#  ('voetgangers', 0.5309497117996216),
#  ('binnenshuis', 0.5212514400482178),
#  ('nauwe', 0.5116783380508423),
#  ('ruimten', 0.5009301900863647),
#  ('vermoeidheid', 0.49301761388778687),
#  ('gemeenschap', 0.4906501770019531),
#  ('huiskamer', 0.48455744981765747),
#  ('paden', 0.4729483127593994)]
