# %%
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec
from gensim.models import Phrases
from gensim.models.phrases import Phrases, Phraser
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import glob
import os
from os import path
import string
import numpy
import re
from __future__ import absolute_import, division, print_function
import pandas as pd
import multiprocessing
import gensim
import random
from tqdm import tqdm
from sklearn.manifold import TSNE
from gensim.models import KeyedVectors
import numpy as np

# %%
os.chdir("D://Scriptie//Data//models")
list_mod = glob.glob('*w2v')
list_mod
# Out:
# ['1815_10yp_bigrams_model.w2v',
#  '1825_10yp_bigrams_model.w2v',
#  '1835_10yp_bigrams_model.w2v',
#  '1845_10yp_bigrams_model.w2v',
#  '1855_10yp_bigrams_model.w2v',
#  '1865_10yp_bigrams_model.w2v',
#  '1875_10yp_bigrams_model.w2v',
#  '1885_10yp_bigrams_model.w2v',
#  '1895_10yp_bigrams_model.w2v',
#  '1905_10yp_bigrams_model.w2v']

# %%
df = pd.DataFrame()

for i in list(range(1815,1906,10)):
    mfn = [m for m in list_mod if int(m[0:4]) == i]
    m = KeyedVectors.load(mfn[0], mmap='r')
    
    if "rijk" in [k for k,v in dict(m.wv.vocab).items()]:
        print(str(i) + ": " + " | ".join(list(dict(m.most_similar("rijk", topn=50)))[0:35]))
        #t = pd.DataFrame(list(dict(m.most_similar("beschaafde_volken", topn=50)))[0:40])
        #t['year'] = i
        #t['score'] = [str(s) + ". " for s in list(t.index)]
        #df = df.append(t)
        #print('')
        print('')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 1815: koningrijk | keizerrijk | schiereiland | rgk | gebied | ryk | iand | gemeenebest | fchiereiland | hertogdom | koninkrijk | vorstendom | rjjk | vereenigde_koningrijk | land | gewest | russische_rijk | rilk | prinsdom | riik | rusfifche_rijk | bondgenootfchap | vaste_land | bet_rijk | moederland | rflk | werelddeel | ons_land | etablissement | rik | stamhuis | geheele_land | laud | kijk | erfgoed
#
# 1825: rgk | koningrijk | kijk | russische_rijk | bijk | land | keizerrijk | rjjk | iand | schiereiland | werelddeel | gewest | ryk | oude_nederland | ons_rijk | turksche_rijk | geheele_koningrijk | britsche_rijk | vorstendom | rjk | gemeenebest | vereenigde_koningrijk | riik | ko_ningrijk | gebied | koninkrijk | laud | koningrijk_polen | erfgoed | vereenigd_koningrijk | rük | middelpunt | prinsdom | moederland | het_rijk
#
# 1835: rgk | koningrijk | land | kijk | keizerrijk | werelddeel | schiereiland | bijk | gemeenebest | laud | iand | vorstendom | rük | russische_rijk | rjjk | ryk | moederland | koninkrijk | gewest | riik | dit_land | rjk | turksche_rijk | rrjk | vaderland | bondgenootschap | europa | vasteland | vorstelijk_huis | schoone_land | ottomannische_rijk | prinsdom | volk | koningrijk_polen | jand
#
# 1845: bijk | kijk | rgk | ryk | land | het_rijk | koningrijk | bet_rijk | rjk | britsche_rijk | rjjk | gewest | russische_rijk | laud | riik | vereenigd_koningrijk | vereenigde_koningrijk | oude_nederland | koninkrijk | hertogdom | hel_rijk | rtjk | iand | duitsche_rijk | moederland | overige_europa | ko_ningrijk | vaderland | keizerrijk | geheele_koningrijk | ons_rijk | russische_keizerrijk | land» | schiereiland | grondbezit
#
# 1855: ryk | kijk | rgk | bijk | koningrijk | rjjk | britsche_rijk | land | rjk | gewest | russische_rijk | grondbezit | laud | chinesche_rijk | het_rijk | turksche_rijk | riik | moederland | overige_europa | keizerrijk | iand | koninkrijk | schiereiland | vereenigde_koningrijk | vereenigd_koningrijk | bet_rijk | geheele_koningrijk | hertogdom | erfgoed | llijk | geheele_schiereiland | hel_rijk | grondgebied | rijksgebied | ottomannische_rijk
#
# 1865: ryk | rgk | koningrijk | rjjk | landje | laud | koninkrijk | rjk | kijk | land | uitgestrekt_rijk | keizerrijk | volk | riik | vorstenhuis | gewest | heelal | bijk | vorstelijk_huis | werelddeel | vorstendom | overige_europa | wingewest | vaderlaud | magtig_rijk | doorluchtig_geslacht | plekje_gronds | rük | britsche_rijk | schiereiland | landschap | hemelsche_rijk | erfgoed | hertogdom | duitsche_rijk
#
# 1875: ryk | rjjk | rgk | rijke | koningrijk | landje | land | gewest | laud | uitgestrekt_rijk | koninkrijk | bijk | uitgestrekt_gebied | rjk | riik | sieraad | vorstendom | rijkste | vorstenhuis | kijk | tijk | hemelsche_rijk | russische_rijk | heelal | volk | rijken | wingewest | plekje_gronds | rük | keizerrijk | doorluchtig_geslacht | erfgoed | britsche_rijk | vaderlaud | eertijds_zoo
#
# 1885: rjjk | rgk | ryk | rijke | land | landje | verarmd | koningrijk | laud | rijkste | rük | rijker | rijken | koninkrijk | rjk | gewest | riik | bloeijend | dierbaar | volk | onschatbare_waarde | uitgestrekt_rijk | zoo_dierbaar | bijk | verknocht | sieraad | naauw_verbonden | wingewest | vorstenhuis | onmetelijk | gezegend | geliefd | vaderlaud | vruchtbaar | onvergelijkelijk
#
# 1895: rgk | rjjk | ryk | koninkrijk | land | rijke | koningrijk | laud | riik | rjk | britsche_rijk | rük | landje | volk | rijkste | uitgestrekt_rijk | vorstenhuis | bijk | brittanje | heelal | wingewest | paradijs | sieraad | dierbaar | rijkst | keizerrijk | rijken | vaderlaud | erfgoed | verarmd | overige_europa | vereenigde_koningrijk | kijk | geboorteland | vorstendom
#
# 1905: rgk | rjjk | ryk | rijke | riik | rijkste | koningrijk | rjk | koninkrijk | bijk | land | laud | landje | rijkst | rük | rijker | bloeiend | britsche_rijk | duitsche_rijk | heelal | vorstenhuis | rgke | vorstendom | schatplichtig | eilandenrijk | rjjke | verarmd | rijken | verwant | grooten_rijkdom | koningshuis | sieraad | natuurschoon | naauw_verbonden | dierbaar

# %%
df.columns = ['t', 'year', 'score']
df
# Out:
#                      t  year score
# 0           middelpunt  1815   0.
# 1               gewest  1815   1.
# 2               eiland  1815   2.
# 3                 laud  1815   3.
# 4      ongelukkig_land  1815   4.
# 5         fchiereiland  1815   5.
# 6                 punt  1815   6.
# 7         schiereiland  1815   7.
# 8          gemeenebest  1815   8.
# 9                 dorp  1815   9.
# 10             gedeehe  1815  10.
# 11         despotismus  1815  11.
# 12             klimaat  1815  12.
# 13                lard  1815  13.
# 14             bolwerk  1815  14.
# 15           oogenbiik  1815  15.
# 16           vaarwater  1815  16.
# 17                rijk  1815  17.
# 18        schoone_land  1815  18.
# 19           vast_punt  1815  19.
# 20       hec_denkbeeld  1815  20.
# 21     zoo_uitgestrekt  1815  21.
# 22          denk_beeld  1815  22.
# 23            voorregt  1815  23.
# 24                punc  1815  24.
# 25              hoekje  1815  25.
# 26                oord  1815  26.
# 27            prinsdom  1815  27.
# 28                iand  1815  28.
# 29            gebergte  1815  29.
# ..                 ...   ...   ...
# 10          koningrijk  1905  10.
# 11   zwarte_werelddeel  1905  11.
# 12      ons_werelddeel  1905  12.
# 13           wingewest  1905  13.
# 14          koninkrijk  1905  14.
# 15         arbeidsveld  1905  15.
# 16    uitgestrekt_rijk  1905  16.
# 17           brandpunt  1905  17.
# 18            goudland  1905  18.
# 19      dit_werelddeel  1905  19.
# 20    menschengeslacht  1905  20.
# 21            paradijs  1905  21.
# 22          wereldrond  1905  22.
# 23       britsche_rijk  1905  23.
# 24             tydperk  1905  24.
# 25       visschersdorp  1905  25.
# 26        verre_westen  1905  26.
# 27            gebergte  1905  27.
# 28    westelijk_europa  1905  28.
# 29              rijkje  1905  29.
# 30  uitgestrekt_gebied  1905  30.
# 31          keizerrijk  1905  31.
# 32        eilandenrijk  1905  32.
# 33                 ras  1905  33.
# 34            bergland  1905  34.
# 35           menschdom  1905  35.
# 36                jand  1905  36.
# 37          strijdperk  1905  37.
# 38       statenverbond  1905  38.
# 39    ongelukkige_land  1905  39.
#
# [160 rows x 3 columns]

# %%
df['txt'] = df["score"].map(str) + df["t"]

os.chdir("C://Users//Ruben//Documents//GitHub//TheForeign//Visualizations//CH2//source-files")
df.to_csv('werelddeel_msm.csv', index=False)

# %%
for i in list(range(1815,1906,10)):
    mfn = [m for m in list_mod if int(m[0:4]) == i]
    m = KeyedVectors.load(mfn[0], mmap='r')
    
    print(i)
    #print(len([k for k,v in dict(m.wv.vocab).items() if "nederlandsche_" in k]))
    for w in [k for k,v in dict(m.wv.vocab).items() if "_natie" in k]:
        print(w)
    print('')
# Out:
# 1815
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
#
# 1825
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
#
# 1835
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
#
# 1845
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
#
# 1855
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
#
# 1865
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
# vreemde_natie
# bevriende_natie
#
# 1875
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
# vreemde_natie
# bevriende_natie
#
# 1885
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
# vreemde_natie
# bevriende_natie
#
# 1895
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
# vreemde_natie
# bevriende_natie
# alle_naties
# andere_naties
# andere_natie
# beide_naties
#
# 1905
# der_natie
# franfche_natie
# geheele_natie
# duitfche_natie
# groote_natie
# gebeele_natie
# hunner_natie
# dier_natie
# spaanfche_natie
# eener_natie
# dappere_natie
# edelmoedige_natie
# engelfche_natie
# nederlandsche_natie
# onafhankelijke_natie
# elke_natie
# vrije_natie
# poolfche_natie
# britfche_natie
# vaderlandsche_natie
# voorde_natie
# zelfde_natie
# fpaanfche_natie
# duitsche_natie
# engelsche_natie
# iedere_natie
# zijner_natie
# fransche_natie
# spaansche_natie
# hollandsche_natie
# gansche_natie
# onzer_natie
# christelijke_natie
# grieksche_natie
# griekfche_natie
# heldhaftige_natie
# grootmoedige_natie
# portugesche_natie
# portugeesche_natie
# portugefche_natie
# britsche_natie
# handeldrijvende_natie
# edele_natie
# hongaarsche_natie
# dankbare_natie
# beschaafde_natie
# naburige_natie
# poolsche_natie
# servische_natie
# verlichte_natie
# dor_natie
# ongelukkige_natie
# tier_natie
# fransehe_natie
# belgische_natie
# getrouwe_natie
# lersche_natie
# onze_natie
# dei_natie
# amerikaansche_natie
# russische_natie
# katholieke_natie
# pruissische_natie
# engelsehe_natie
# italiaansche_natie
# mexicaansche_natie
# deensche_natie
# vreemde_natie
# bevriende_natie
# alle_naties
# andere_naties
# andere_natie
# beide_naties
# verschillende_naties
# kleine_natie
# kleine_naties

# %%
df = list()

for i in list(range(1815,1906,10)):
    mfn = [m for m in list_mod if int(m[0:4]) == i]
    m = KeyedVectors.load(mfn[0], mmap='r')

    print('')
    print(i)
    for w in [k for k,v in dict(m.wv.vocab).items() if "binnenlandsche_" in k]:
        tmp = dict(m.most_similar(w, topn=500000))

        for x in [x for x,y in tmp.items() if y > 0.4]:
            if "buitenlandsche_" in x:
                weight = m.similarity(w,x)
                t = [w,x,weight,i]
                df.append(t)
                print(w, "  |  ", x)
# Out:
# 1815
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# binnenlandsche_zaten   |   buitenlandsche_ziken
# binnenlandsche_zaten   |   buitenlandsche_taken
# binnenlandsche_zaten   |   buitenlandsche_zaken
# binnenlandsche_zaken   |   buitenlandsche_zaken
# binnenlandsche_zaken   |   buitenlandsche_ziken
# binnenlandsche_zaken   |   buitenlandsche_taken
# binnenlandsche_zsken   |   buitenlandsche_taken
# binnenlandsche_zsken   |   buitenlandsche_ziken
# binnenlandsche_zsken   |   buitenlandsche_zaken
# binnenlandsche_zsken   |   buitenlandsche_hoven
# binnenlandsche_zakeu   |   buitenlandsche_ziken
# binnenlandsche_zakeu   |   buitenlandsche_taken
# binnenlandsche_zakeu   |   buitenlandsche_zaken
# binnenlandsche_ziken   |   buitenlandsche_ziken
# binnenlandsche_ziken   |   buitenlandsche_zaken
# binnenlandsche_ziken   |   buitenlandsche_taken
# binnenlandsche_onlusten   |   buitenlandsche_zeevaart
# binnenlandsche_paspoorten   |   buitenlandsche_zeevaart
# binnenlandsche_paspoorten   |   buitenlandsche_bieren
# binnenlandsche_paspoorten   |   buitenlandsche_paspoorten
# binnenlandsche_paspoorten   |   buitenlandsche_producten
# binnenlandsche_paspoorten   |   buitenlandsche_zeep
# binnenlandsche_paspoorten   |   buitenlandsche_harde
# binnenlandsche_paspoorten   |   buitenlandsche_fondsen
# binnenlandsche_paspoorten   |   buitenlandsche_handel
# binnenlandsche_berigten   |   buitenlandsche_berigten
# binnenlandsche_berigten   |   buitenlandsche_rerigten
# binnenlandsche_effecten   |   buitenlandsche_effecten
# binnenlandsche_effecten   |   buitenlandsche_zeep
# binnenlandsche_effecten   |   buitenlandsche_bieren
# binnenlandsche_effecten   |   buitenlandsche_harde
# binnenlandsche_effecten   |   buitenlandsche_fondfen
# binnenlandsche_effecten   |   buitenlandsche_fondsen
# binnenlandsche_effecten   |   buitenlandsche_steenkolen
# binnenlandsche_effecten   |   buitenlandsche_produkten
# binnenlandsche_effecten   |   buitenlandsche_geldleeningen
# binnenlandsche_effecten   |   buitenlandsche_producten
# binnenlandsche_effecten   |   buitenlandsche_rerigten
# binnenlandsche_zaleen   |   buitenlandsche_ziken
# binnenlandsche_zaleen   |   buitenlandsche_taken
# binnenlandsche_zaleen   |   buitenlandsche_zaken
# binnenlandsche_zaleen   |   buitenlandsche_rerigten
# binnenlandsche_negotiatien   |   buitenlandsche_effecten
# binnenlandsche_negotiatien   |   buitenlandsche_wijn
# binnenlandsche_negotiatien   |   buitenlandsche_effekten
# binnenlandsche_negotiatien   |   buitenlandsche_zeep
# binnenlandsche_negotiatien   |   buitenlandsche_harde
# binnenlandsche_negotiatien   |   buitenlandsche_bieren
# binnenlandsche_negotiatien   |   buitenlandsche_beurt
# binnenlandsche_negotiatien   |   buitenlandsche_fondfen
# binnenlandsche_negotiatien   |   buitenlandsche_paspoorten
# binnenlandsche_negotiatien   |   buitenlandsche_scheepvaart
# binnenlandsche_negotiatien   |   buitenlandsche_brandewijn
# binnenlandsche_negotiatien   |   buitenlandsche_steenkolen
# binnenlandsche_negotiatien   |   buitenlandsche_rerigten
# binnenlandsche_negotiatien   |   buitenlandsche_fondsen
# binnenlandsche_negotiatien   |   buitenlandsche_voorkomende
# binnenlandsche_zake   |   buitenlandsche_ziken
# binnenlandsche_zake   |   buitenlandsche_taken
# binnenlandsche_zake   |   buitenlandsche_zaken
# binnenlandsche_vaart   |   buitenlandsche_bieren
# binnenlandsche_vaart   |   buitenlandsche_producten
# binnenlandsche_vaart   |   buitenlandsche_steenkolen
# binnenlandsche_vaart   |   buitenlandsche_harde
# binnenlandsche_vaart   |   buitenlandsche_brandewijn
# binnenlandsche_vaart   |   buitenlandsche_zeep
# binnenlandsche_vaart   |   buitenlandsche_produkten
# binnenlandsche_vaart   |   buitenlandsche_effecten
# binnenlandsche_vaart   |   buitenlandsche_wijn
# binnenlandsche_vaart   |   buitenlandsche_fondfen
# binnenlandsche_vaart   |   buitenlandsche_handel
# binnenlandsche_vaart   |   buitenlandsche_verzending
# binnenlandsche_vaart   |   buitenlandsche_granen
# binnenlandsche_vaart   |   buitenlandsche_fondsen
# binnenlandsche_vaart   |   buitenlandsche_bezittingen
# binnenlandsche_vaart   |   buitenlandsche_paspoorten
# binnenlandsche_vaart   |   buitenlandsche_zeevaart
# binnenlandsche_zakea   |   buitenlandsche_ziken
# binnenlandsche_zakea   |   buitenlandsche_taken
# binnenlandsche_zakea   |   buitenlandsche_zaken
# binnenlandsche_zakea   |   buitenlandsche_hoven
# binnenlandsche_zakenen   |   buitenlandsche_ziken
# binnenlandsche_zakenen   |   buitenlandsche_taken
# binnenlandsche_zakenen   |   buitenlandsche_rerigten
# binnenlandsche_zakenen   |   buitenlandsche_paspoorten
# binnenlandsche_zakenen   |   buitenlandsche_bieren
# binnenlandsche_zakenen   |   buitenlandsche_harde
# binnenlandsche_zakenen   |   buitenlandsche_zaken
# binnenlandsche_za   |   buitenlandsche_taken
# binnenlandsche_za   |   buitenlandsche_ziken
# binnenlandsche_za   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_ziken
# binnenlandsche_aken   |   buitenlandsche_taken
# binnenlandsche_aken   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_rerigten
# binnenlandsche_aken   |   buitenlandsche_aangelegenheden
# binnenlandsche_welvaart   |   buitenlandsche_bezittingen
# binnenlandsche_welvaart   |   buitenlandsche_handel
# binnenlandsche_welvaart   |   buitenlandsche_betrekkingen
# binnenlandsche_znken   |   buitenlandsche_zaken
# binnenlandsche_znken   |   buitenlandsche_ziken
# binnenlandsche_znken   |   buitenlandsche_taken
# binnenlandsche_bieren   |   buitenlandsche_bieren
# binnenlandsche_bieren   |   buitenlandsche_producten
# binnenlandsche_bieren   |   buitenlandsche_steenkolen
# binnenlandsche_bieren   |   buitenlandsche_harde
# binnenlandsche_bieren   |   buitenlandsche_zeep
# binnenlandsche_bieren   |   buitenlandsche_brandewijn
# binnenlandsche_bieren   |   buitenlandsche_produkten
# binnenlandsche_bieren   |   buitenlandsche_wijn
# binnenlandsche_bieren   |   buitenlandsche_effecten
# binnenlandsche_bieren   |   buitenlandsche_fondsen
# binnenlandsche_bieren   |   buitenlandsche_verzending
# binnenlandsche_bieren   |   buitenlandsche_voorkomende
# binnenlandsche_bieren   |   buitenlandsche_beurt
# binnenlandsche_bieren   |   buitenlandsche_paspoorten
# binnenlandsche_bieren   |   buitenlandsche_fondfen
# binnenlandsche_bieren   |   buitenlandsche_granen
# binnenlandsche_bieren   |   buitenlandsche_geldleeningen
# binnenlandsche_steenkolen   |   buitenlandsche_bieren
# binnenlandsche_steenkolen   |   buitenlandsche_producten
# binnenlandsche_steenkolen   |   buitenlandsche_zeep
# binnenlandsche_steenkolen   |   buitenlandsche_produkten
# binnenlandsche_steenkolen   |   buitenlandsche_harde
# binnenlandsche_steenkolen   |   buitenlandsche_brandewijn
# binnenlandsche_steenkolen   |   buitenlandsche_steenkolen
# binnenlandsche_steenkolen   |   buitenlandsche_wijn
# binnenlandsche_steenkolen   |   buitenlandsche_effecten
# binnenlandsche_steenkolen   |   buitenlandsche_verzending
# binnenlandsche_steenkolen   |   buitenlandsche_fondfen
# binnenlandsche_steenkolen   |   buitenlandsche_paspoorten
# binnenlandsche_steenkolen   |   buitenlandsche_handel
# binnenlandsche_steenkolen   |   buitenlandsche_fondsen
# binnenlandsche_steenkolen   |   buitenlandsche_zeevaart
# binnenlandsche_steenkolen   |   buitenlandsche_granen
# binnenlandsche_steenkolen   |   buitenlandsche_beurt
# binnenlandsche_circulatie   |   buitenlandsche_harde
# binnenlandsche_circulatie   |   buitenlandsche_mogendheid
# binnenlandsche_circulatie   |   buitenlandsche_bieren
# binnenlandsche_circulatie   |   buitenlandsche_steenkolen
# binnenlandsche_scheepvaart   |   buitenlandsche_producten
# binnenlandsche_scheepvaart   |   buitenlandsche_produkten
# binnenlandsche_scheepvaart   |   buitenlandsche_bieren
# binnenlandsche_scheepvaart   |   buitenlandsche_zeep
# binnenlandsche_scheepvaart   |   buitenlandsche_effecten
# binnenlandsche_scheepvaart   |   buitenlandsche_wijn
# binnenlandsche_scheepvaart   |   buitenlandsche_steenkolen
# binnenlandsche_scheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_scheepvaart   |   buitenlandsche_fondsen
# binnenlandsche_scheepvaart   |   buitenlandsche_beurt
# binnenlandsche_scheepvaart   |   buitenlandsche_verzending
# binnenlandsche_scheepvaart   |   buitenlandsche_harde
# binnenlandsche_scheepvaart   |   buitenlandsche_handel
# binnenlandsche_scheepvaart   |   buitenlandsche_vijanden
# binnenlandsche_scheepvaart   |   buitenlandsche_granen
# binnenlandsche_scheepvaart   |   buitenlandsche_fondfen
# binnenlandsche_nijverheid   |   buitenlandsche_verzending
# binnenlandsche_nijverheid   |   buitenlandsche_handel
# binnenlandsche_nijverheid   |   buitenlandsche_producten
# binnenlandsche_nijverheid   |   buitenlandsche_produkten
# binnenlandsche_effekten   |   buitenlandsche_effekten
# binnenlandsche_effekten   |   buitenlandsche_rerigten
# binnenlandsche_effekten   |   buitenlandsche_harde
# binnenlandsche_effekten   |   buitenlandsche_effecten
# binnenlandsche_effekten   |   buitenlandsche_geldleeningen
# binnenlandsche_effekten   |   buitenlandsche_voorkomende
# binnenlandsche_effekten   |   buitenlandsche_bieren
# binnenlandsche_consumtie   |   buitenlandsche_verzending
# binnenlandsche_consumtie   |   buitenlandsche_handel
# binnenlandsche_consumtie   |   buitenlandsche_bieren
# binnenlandsche_consumtie   |   buitenlandsche_harde
# binnenlandsche_consumtie   |   buitenlandsche_brandewijn
# binnenlandsche_consumtie   |   buitenlandsche_granen
# binnenlandsche_consumtie   |   buitenlandsche_zeep
# binnenlandsche_consumtie   |   buitenlandsche_producten
# binnenlandsche_consumtie   |   buitenlandsche_fondsen
# binnenlandsche_consumtie   |   buitenlandsche_paspoorten
# binnenlandsche_consumtie   |   buitenlandsche_effecten
# binnenlandsche_consumtie   |   buitenlandsche_zeevaart
# binnenlandsche_consumtie   |   buitenlandsche_wijn
# binnenlandsche_consumtie   |   buitenlandsche_produkten
# binnenlandsche_consumtie   |   buitenlandsche_steenkolen
# binnenlandsche_zeep   |   buitenlandsche_steenkolen
# binnenlandsche_zeep   |   buitenlandsche_bieren
# binnenlandsche_zeep   |   buitenlandsche_harde
# binnenlandsche_zeep   |   buitenlandsche_zeep
# binnenlandsche_zeep   |   buitenlandsche_producten
# binnenlandsche_zeep   |   buitenlandsche_geldleeningen
# binnenlandsche_zeep   |   buitenlandsche_produkten
# binnenlandsche_zeep   |   buitenlandsche_beurt
# binnenlandsche_zeep   |   buitenlandsche_wijn
# binnenlandsche_zeep   |   buitenlandsche_staatkunde
# binnenlandsche_zeep   |   buitenlandsche_paspoorten
# binnenlandsche_zeep   |   buitenlandsche_brandewijn
# binnenlandsche_zeep   |   buitenlandsche_rerigten
# binnenlandsche_zeep   |   buitenlandsche_bezittingen
# binnenlandsche_zeep   |   buitenlandsche_voorkomende
# binnenlandsche_zeep   |   buitenlandsche_effecten
# binnenlandsche_zeep   |   buitenlandsche_verzending
# binnenlandsche_zeep   |   buitenlandsche_vijanden
# binnenlandsche_fcheepvaart   |   buitenlandsche_harde
# binnenlandsche_fcheepvaart   |   buitenlandsche_bieren
# binnenlandsche_fcheepvaart   |   buitenlandsche_paspoorten
# binnenlandsche_fcheepvaart   |   buitenlandsche_produkten
# binnenlandsche_fcheepvaart   |   buitenlandsche_producten
# binnenlandsche_fcheepvaart   |   buitenlandsche_wijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_handel
# binnenlandsche_fcheepvaart   |   buitenlandsche_verzending
# binnenlandsche_aangelegenheden   |   buitenlandsche_mogendheden
# binnenlandsche_aangelegenheden   |   buitenlandsche_vijanden
# binnenlandsche_aangelegenheden   |   buitenlandsche_mogendheid
# binnenlandsche_aangelegenheden   |   buitenlandsche_betrekkingen
#
# 1825
# binnenlandsche_zaten   |   buitenlandsche_taken
# binnenlandsche_zaten   |   buitenlandsche_ziken
# binnenlandsche_zaten   |   buitenlandsche_aken
# binnenlandsche_zaten   |   buitenlandsche_zaken
# binnenlandsche_zaten   |   buitenlandsche_«aken
# binnenlandsche_zaten   |   buitenlandsche_zakeu
# binnenlandsche_zaken   |   buitenlandsche_zaken
# binnenlandsche_zaken   |   buitenlandsche_zakeu
# binnenlandsche_zaken   |   buitenlandsche_ziken
# binnenlandsche_zaken   |   buitenlandsche_aken
# binnenlandsche_zaken   |   buitenlandsche_taken
# binnenlandsche_zsken   |   buitenlandsche_taken
# binnenlandsche_zsken   |   buitenlandsche_ziken
# binnenlandsche_zsken   |   buitenlandsche_zaken
# binnenlandsche_zsken   |   buitenlandsche_zakeu
# binnenlandsche_zsken   |   buitenlandsche_aken
# binnenlandsche_zsken   |   buitenlandsche_«aken
# binnenlandsche_zsken   |   buitenlandsche_aangelegenheden
# binnenlandsche_zsken   |   buitenlandsche_hoven
# binnenlandsche_zakeu   |   buitenlandsche_ziken
# binnenlandsche_zakeu   |   buitenlandsche_taken
# binnenlandsche_zakeu   |   buitenlandsche_aken
# binnenlandsche_zakeu   |   buitenlandsche_zaken
# binnenlandsche_zakeu   |   buitenlandsche_zakeu
# binnenlandsche_zakeu   |   buitenlandsche_«aken
# binnenlandsche_ziken   |   buitenlandsche_ziken
# binnenlandsche_ziken   |   buitenlandsche_taken
# binnenlandsche_ziken   |   buitenlandsche_zaken
# binnenlandsche_ziken   |   buitenlandsche_aken
# binnenlandsche_ziken   |   buitenlandsche_zakeu
# binnenlandsche_ziken   |   buitenlandsche_«aken
# binnenlandsche_onlusten   |   buitenlandsche_handel
# binnenlandsche_onlusten   |   buitenlandsche_staatkunde
# binnenlandsche_onlusten   |   buitenlandsche_vijanden
# binnenlandsche_onlusten   |   buitenlandsche_mededinging
# binnenlandsche_onlusten   |   buitenlandsche_betrekkingen
# binnenlandsche_paspoorten   |   buitenlandsche_paspoorten
# binnenlandsche_paspoorten   |   buitenlandsche_zeep
# binnenlandsche_paspoorten   |   buitenlandsche_granen
# binnenlandsche_paspoorten   |   buitenlandsche_producten
# binnenlandsche_paspoorten   |   buitenlandsche_bieren
# binnenlandsche_paspoorten   |   buitenlandsche_zeevaart
# binnenlandsche_paspoorten   |   buitenlandsche_verzending
# binnenlandsche_paspoorten   |   buitenlandsche_voortbrengselen
# binnenlandsche_paspoorten   |   buitenlandsche_orders
# binnenlandsche_paspoorten   |   buitenlandsche_handel
# binnenlandsche_paspoorten   |   buitenlandsche_harde
# binnenlandsche_berigten   |   buitenlandsche_berigten
# binnenlandsche_effecten   |   buitenlandsche_effecten
# binnenlandsche_effecten   |   buitenlandsche_fondfen
# binnenlandsche_effecten   |   buitenlandsche_harde
# binnenlandsche_effecten   |   buitenlandsche_effekten
# binnenlandsche_effecten   |   buitenlandsche_bieren
# binnenlandsche_effecten   |   buitenlandsche_zeep
# binnenlandsche_effecten   |   buitenlandsche_geldleeningen
# binnenlandsche_effecten   |   buitenlandsche_fondsen
# binnenlandsche_effecten   |   buitenlandsche_produkten
# binnenlandsche_effecten   |   buitenlandsche_steenkolen
# binnenlandsche_zaleen   |   buitenlandsche_taken
# binnenlandsche_zaleen   |   buitenlandsche_ziken
# binnenlandsche_zaleen   |   buitenlandsche_aken
# binnenlandsche_zaleen   |   buitenlandsche_«aken
# binnenlandsche_zaleen   |   buitenlandsche_zakeu
# binnenlandsche_zaleen   |   buitenlandsche_zaken
# binnenlandsche_zaleen   |   buitenlandsche_politiek
# binnenlandsche_zaleen   |   buitenlandsche_belrekkingen
# binnenlandsche_zaleen   |   buitenlandsche_rerigten
# binnenlandsche_negotiatien   |   buitenlandsche_effecten
# binnenlandsche_negotiatien   |   buitenlandsche_harde
# binnenlandsche_negotiatien   |   buitenlandsche_wijn
# binnenlandsche_negotiatien   |   buitenlandsche_effekten
# binnenlandsche_negotiatien   |   buitenlandsche_bieren
# binnenlandsche_negotiatien   |   buitenlandsche_beurt
# binnenlandsche_negotiatien   |   buitenlandsche_rerigten
# binnenlandsche_negotiatien   |   buitenlandsche_zeep
# binnenlandsche_negotiatien   |   buitenlandsche_paspoorten
# binnenlandsche_negotiatien   |   buitenlandsche_fondfen
# binnenlandsche_negotiatien   |   buitenlandsche_steenkolen
# binnenlandsche_negotiatien   |   buitenlandsche_scheepvaart
# binnenlandsche_negotiatien   |   buitenlandsche_verzending
# binnenlandsche_negotiatien   |   buitenlandsche_geldleeningen
# binnenlandsche_negotiatien   |   buitenlandsche_voorkomende
# binnenlandsche_zake   |   buitenlandsche_taken
# binnenlandsche_zake   |   buitenlandsche_ziken
# binnenlandsche_zake   |   buitenlandsche_aken
# binnenlandsche_zake   |   buitenlandsche_«aken
# binnenlandsche_zake   |   buitenlandsche_zakeu
# binnenlandsche_zake   |   buitenlandsche_zaken
# binnenlandsche_zake   |   buitenlandsche_belrekkingen
# binnenlandsche_zake   |   buitenlandsche_politiek
# binnenlandsche_zake   |   buitenlandsche_geassocieerden
# binnenlandsche_zake   |   buitenlandsche_agenten
# binnenlandsche_vaart   |   buitenlandsche_producten
# binnenlandsche_vaart   |   buitenlandsche_bieren
# binnenlandsche_vaart   |   buitenlandsche_zeep
# binnenlandsche_vaart   |   buitenlandsche_steenkolen
# binnenlandsche_vaart   |   buitenlandsche_brandewijn
# binnenlandsche_vaart   |   buitenlandsche_produkten
# binnenlandsche_vaart   |   buitenlandsche_harde
# binnenlandsche_vaart   |   buitenlandsche_granen
# binnenlandsche_vaart   |   buitenlandsche_effecten
# binnenlandsche_vaart   |   buitenlandsche_handel
# binnenlandsche_vaart   |   buitenlandsche_wijn
# binnenlandsche_vaart   |   buitenlandsche_verzending
# binnenlandsche_vaart   |   buitenlandsche_fondfen
# binnenlandsche_zakea   |   buitenlandsche_ziken
# binnenlandsche_zakea   |   buitenlandsche_taken
# binnenlandsche_zakea   |   buitenlandsche_aken
# binnenlandsche_zakea   |   buitenlandsche_zakeu
# binnenlandsche_zakea   |   buitenlandsche_zaken
# binnenlandsche_zakea   |   buitenlandsche_«aken
# binnenlandsche_zakea   |   buitenlandsche_hoven
# binnenlandsche_zakenen   |   buitenlandsche_taken
# binnenlandsche_zakenen   |   buitenlandsche_ziken
# binnenlandsche_zakenen   |   buitenlandsche_rerigten
# binnenlandsche_zakenen   |   buitenlandsche_aken
# binnenlandsche_zakenen   |   buitenlandsche_bieren
# binnenlandsche_zakenen   |   buitenlandsche_«aken
# binnenlandsche_zakenen   |   buitenlandsche_paspoorten
# binnenlandsche_zakenen   |   buitenlandsche_harde
# binnenlandsche_zakenen   |   buitenlandsche_produkten
# binnenlandsche_zakenen   |   buitenlandsche_belrekkingen
# binnenlandsche_zakenen   |   buitenlandsche_geldleeningen
# binnenlandsche_za   |   buitenlandsche_taken
# binnenlandsche_za   |   buitenlandsche_ziken
# binnenlandsche_za   |   buitenlandsche_aken
# binnenlandsche_za   |   buitenlandsche_zakeu
# binnenlandsche_za   |   buitenlandsche_«aken
# binnenlandsche_za   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_ziken
# binnenlandsche_aken   |   buitenlandsche_taken
# binnenlandsche_aken   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_aken
# binnenlandsche_aken   |   buitenlandsche_«aken
# binnenlandsche_aken   |   buitenlandsche_zakeu
# binnenlandsche_welvaart   |   buitenlandsche_bezittingen
# binnenlandsche_welvaart   |   buitenlandsche_handel
# binnenlandsche_welvaart   |   buitenlandsche_mededinging
# binnenlandsche_znken   |   buitenlandsche_ziken
# binnenlandsche_znken   |   buitenlandsche_taken
# binnenlandsche_znken   |   buitenlandsche_zaken
# binnenlandsche_znken   |   buitenlandsche_zakeu
# binnenlandsche_znken   |   buitenlandsche_aken
# binnenlandsche_znken   |   buitenlandsche_«aken
# binnenlandsche_bieren   |   buitenlandsche_bieren
# binnenlandsche_bieren   |   buitenlandsche_producten
# binnenlandsche_bieren   |   buitenlandsche_steenkolen
# binnenlandsche_bieren   |   buitenlandsche_harde
# binnenlandsche_bieren   |   buitenlandsche_zeep
# binnenlandsche_bieren   |   buitenlandsche_produkten
# binnenlandsche_bieren   |   buitenlandsche_brandewijn
# binnenlandsche_bieren   |   buitenlandsche_wijn
# binnenlandsche_bieren   |   buitenlandsche_effecten
# binnenlandsche_bieren   |   buitenlandsche_likeuren
# binnenlandsche_bieren   |   buitenlandsche_verzending
# binnenlandsche_bieren   |   buitenlandsche_granen
# binnenlandsche_bieren   |   buitenlandsche_beurt
# binnenlandsche_bieren   |   buitenlandsche_voorkomende
# binnenlandsche_bieren   |   buitenlandsche_paspoorten
# binnenlandsche_bieren   |   buitenlandsche_geldleeningen
# binnenlandsche_bieren   |   buitenlandsche_handel
# binnenlandsche_bieren   |   buitenlandsche_fondfen
# binnenlandsche_bieren   |   buitenlandsche_voortbrengselen
# binnenlandsche_steenkolen   |   buitenlandsche_bieren
# binnenlandsche_steenkolen   |   buitenlandsche_producten
# binnenlandsche_steenkolen   |   buitenlandsche_zeep
# binnenlandsche_steenkolen   |   buitenlandsche_harde
# binnenlandsche_steenkolen   |   buitenlandsche_brandewijn
# binnenlandsche_steenkolen   |   buitenlandsche_steenkolen
# binnenlandsche_steenkolen   |   buitenlandsche_produkten
# binnenlandsche_steenkolen   |   buitenlandsche_wijn
# binnenlandsche_steenkolen   |   buitenlandsche_verzending
# binnenlandsche_steenkolen   |   buitenlandsche_effecten
# binnenlandsche_steenkolen   |   buitenlandsche_fondfen
# binnenlandsche_steenkolen   |   buitenlandsche_handel
# binnenlandsche_steenkolen   |   buitenlandsche_granen
# binnenlandsche_steenkolen   |   buitenlandsche_paspoorten
# binnenlandsche_steenkolen   |   buitenlandsche_zeevaart
# binnenlandsche_steenkolen   |   buitenlandsche_likeuren
# binnenlandsche_steenkolen   |   buitenlandsche_markten
# binnenlandsche_steenkolen   |   buitenlandsche_geldleeningen
# binnenlandsche_steenkolen   |   buitenlandsche_beurt
# binnenlandsche_steenkolen   |   buitenlandsche_voortbrengselen
# binnenlandsche_steenkolen   |   buitenlandsche_orders
# binnenlandsche_steenkolen   |   buitenlandsche_verzendingen
# binnenlandsche_circulatie   |   buitenlandsche_harde
# binnenlandsche_circulatie   |   buitenlandsche_bezittingen
# binnenlandsche_circulatie   |   buitenlandsche_geassocieerden
# binnenlandsche_circulatie   |   buitenlandsche_belrekkingen
# binnenlandsche_circulatie   |   buitenlandsche_bieren
# binnenlandsche_circulatie   |   buitenlandsche_steenkolen
# binnenlandsche_circulatie   |   buitenlandsche_zeep
# binnenlandsche_scheepvaart   |   buitenlandsche_producten
# binnenlandsche_scheepvaart   |   buitenlandsche_zeep
# binnenlandsche_scheepvaart   |   buitenlandsche_granen
# binnenlandsche_scheepvaart   |   buitenlandsche_produkten
# binnenlandsche_scheepvaart   |   buitenlandsche_handel
# binnenlandsche_scheepvaart   |   buitenlandsche_bieren
# binnenlandsche_scheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_scheepvaart   |   buitenlandsche_effecten
# binnenlandsche_scheepvaart   |   buitenlandsche_markten
# binnenlandsche_scheepvaart   |   buitenlandsche_verzending
# binnenlandsche_scheepvaart   |   buitenlandsche_orders
# binnenlandsche_scheepvaart   |   buitenlandsche_verzendingen
# binnenlandsche_nijverheid   |   buitenlandsche_verzending
# binnenlandsche_nijverheid   |   buitenlandsche_verzendingen
# binnenlandsche_nijverheid   |   buitenlandsche_handel
# binnenlandsche_nijverheid   |   buitenlandsche_commissien
# binnenlandsche_nijverheid   |   buitenlandsche_orders
# binnenlandsche_nijverheid   |   buitenlandsche_produkten
# binnenlandsche_nijverheid   |   buitenlandsche_markten
# binnenlandsche_nijverheid   |   buitenlandsche_producten
# binnenlandsche_nijverheid   |   buitenlandsche_geldleeningen
# binnenlandsche_nijverheid   |   buitenlandsche_effecten
# binnenlandsche_effekten   |   buitenlandsche_effekten
# binnenlandsche_effekten   |   buitenlandsche_harde
# binnenlandsche_effekten   |   buitenlandsche_rerigten
# binnenlandsche_consumtie   |   buitenlandsche_verzending
# binnenlandsche_consumtie   |   buitenlandsche_handel
# binnenlandsche_consumtie   |   buitenlandsche_granen
# binnenlandsche_consumtie   |   buitenlandsche_orders
# binnenlandsche_consumtie   |   buitenlandsche_verzendingen
# binnenlandsche_consumtie   |   buitenlandsche_zeep
# binnenlandsche_consumtie   |   buitenlandsche_brandewijn
# binnenlandsche_consumtie   |   buitenlandsche_bieren
# binnenlandsche_consumtie   |   buitenlandsche_markten
# binnenlandsche_consumtie   |   buitenlandsche_harde
# binnenlandsche_consumtie   |   buitenlandsche_voortbrengselen
# binnenlandsche_consumtie   |   buitenlandsche_commissien
# binnenlandsche_consumtie   |   buitenlandsche_zeevaart
# binnenlandsche_consumtie   |   buitenlandsche_producten
# binnenlandsche_consumtie   |   buitenlandsche_likeuren
# binnenlandsche_consumtie   |   buitenlandsche_wijn
# binnenlandsche_consumtie   |   buitenlandsche_mededinging
# binnenlandsche_consumtie   |   buitenlandsche_fondsen
# binnenlandsche_consumtie   |   buitenlandsche_effecten
# binnenlandsche_consumtie   |   buitenlandsche_produkten
# binnenlandsche_consumtie   |   buitenlandsche_steenkolen
# binnenlandsche_zeep   |   buitenlandsche_bieren
# binnenlandsche_zeep   |   buitenlandsche_steenkolen
# binnenlandsche_zeep   |   buitenlandsche_producten
# binnenlandsche_zeep   |   buitenlandsche_harde
# binnenlandsche_zeep   |   buitenlandsche_zeep
# binnenlandsche_zeep   |   buitenlandsche_produkten
# binnenlandsche_zeep   |   buitenlandsche_brandewijn
# binnenlandsche_zeep   |   buitenlandsche_effecten
# binnenlandsche_zeep   |   buitenlandsche_paspoorten
# binnenlandsche_zeep   |   buitenlandsche_geldleeningen
# binnenlandsche_zeep   |   buitenlandsche_likeuren
# binnenlandsche_zeep   |   buitenlandsche_wijn
# binnenlandsche_zeep   |   buitenlandsche_verzending
# binnenlandsche_zeep   |   buitenlandsche_voorkomende
# binnenlandsche_zeep   |   buitenlandsche_belrekkingen
# binnenlandsche_zeep   |   buitenlandsche_leeningen
# binnenlandsche_zeep   |   buitenlandsche_voortbrengselen
# binnenlandsche_zeep   |   buitenlandsche_politiek
# binnenlandsche_zeep   |   buitenlandsche_beurt
# binnenlandsche_fcheepvaart   |   buitenlandsche_produkten
# binnenlandsche_fcheepvaart   |   buitenlandsche_harde
# binnenlandsche_fcheepvaart   |   buitenlandsche_bieren
# binnenlandsche_fcheepvaart   |   buitenlandsche_paspoorten
# binnenlandsche_fcheepvaart   |   buitenlandsche_verzending
# binnenlandsche_fcheepvaart   |   buitenlandsche_effecten
# binnenlandsche_fcheepvaart   |   buitenlandsche_wijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_producten
# binnenlandsche_fcheepvaart   |   buitenlandsche_tijdschriften
# binnenlandsche_fcheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_verzendingen
# binnenlandsche_fcheepvaart   |   buitenlandsche_belrekkingen
# binnenlandsche_fcheepvaart   |   buitenlandsche_handel
# binnenlandsche_aangelegenheden   |   buitenlandsche_betrekkingen
# binnenlandsche_aangelegenheden   |   buitenlandsche_aangelegenheden
# binnenlandsche_aangelegenheden   |   buitenlandsche_staatkunde
# binnenlandsche_aangelegenheden   |   buitenlandsche_mogendheden
# binnenlandsche_aangelegenheden   |   buitenlandsche_vijanden
# binnenlandsche_aangelegenheden   |   buitenlandsche_politiek
# binnenlandsche_aangelegenheden   |   buitenlandsche_handel
# binnenlandsche_aangelegenheden   |   buitenlandsche_belrekkingen
# binnenlandsche_aangelegenheden   |   buitenlandsche_mogendheid
# binnenlandsche_aangelegenheden   |   buitenlandsche_markten
# binnenlandsche_aangelegenheden   |   buitenlandsche_schuld
# binnenlandsche_aangelegenheden   |   buitenlandsche_bezittingen
# binnenlandsche_«aken   |   buitenlandsche_taken
# binnenlandsche_«aken   |   buitenlandsche_ziken
# binnenlandsche_«aken   |   buitenlandsche_zaken
# binnenlandsche_«aken   |   buitenlandsche_aken
# binnenlandsche_«aken   |   buitenlandsche_«aken
# binnenlandsche_«aken   |   buitenlandsche_zakeu
# binnenlandsche_«aken   |   buitenlandsche_agenten
# binnenlandsche_«aken   |   buitenlandsche_politiek
# binnenlandsche_«aken   |   buitenlandsche_belrekkingen
# binnenlandsche_fabrijken   |   buitenlandsche_belrekkingen
# binnenlandsche_fabrijken   |   buitenlandsche_markten
# binnenlandsche_fabrijken   |   buitenlandsche_commissien
# binnenlandsche_fabrijken   |   buitenlandsche_geleerden
# binnenlandsche_fabrijken   |   buitenlandsche_mededinging
# binnenlandsche_fabrijken   |   buitenlandsche_politiek
# binnenlandsche_fabrijken   |   buitenlandsche_voortbrengselen
# binnenlandsche_fabrijken   |   buitenlandsche_agenten
# binnenlandsche_gemeenschap   |   buitenlandsche_belrekkingen
# binnenlandsche_gemeenschap   |   buitenlandsche_politiek
# binnenlandsche_gemeenschap   |   buitenlandsche_geassocieerden
# binnenlandsche_gemeenschap   |   buitenlandsche_bezittingen
# binnenlandsche_gemeenschap   |   buitenlandsche_commissien
# binnenlandsche_gemeenschap   |   buitenlandsche_mededinging
# binnenlandsche_gemeenschap   |   buitenlandsche_zendingen
# binnenlandsche_gemeenschap   |   buitenlandsche_handel
# binnenlandsche_gemeenschap   |   buitenlandsche_voortbrengselen
# binnenlandsche_vijanden   |   buitenlandsche_vijanden
# binnenlandsche_vijanden   |   buitenlandsche_belrekkingen
# binnenlandsche_vijanden   |   buitenlandsche_mededinging
# binnenlandsche_vijanden   |   buitenlandsche_politiek
# binnenlandsche_vijanden   |   buitenlandsche_mogendheid
# binnenlandsche_vijanden   |   buitenlandsche_commissien
# binnenlandsche_vijanden   |   buitenlandsche_voortbrengselen
# binnenlandsche_vijanden   |   buitenlandsche_markten
# binnenlandsche_twisten   |   buitenlandsche_mededinging
# binnenlandsche_twisten   |   buitenlandsche_geassocieerden
# binnenlandsche_twisten   |   buitenlandsche_«aken
# binnenlandsche_rust   |   buitenlandsche_mogendheden
# binnenlandsche_rust   |   buitenlandsche_betrekkingen
# binnenlandsche_rust   |   buitenlandsche_vijanden
# binnenlandsche_rust   |   buitenlandsche_politiek
# binnenlandsche_rust   |   buitenlandsche_staatkunde
# binnenlandsche_rust   |   buitenlandsche_belrekkingen
# binnenlandsche_berichten   |   buitenlandsche_«aken
# binnenlandsche_berichten   |   buitenlandsche_rerigten
# binnenlandsche_berichten   |   buitenlandsche_geassocieerden
# binnenlandsche_berichten   |   buitenlandsche_belrekkingen
# binnenlandsche_berichten   |   buitenlandsche_voortbrengselen
# binnenlandsche_berichten   |   buitenlandsche_commissien
# binnenlandsche_berichten   |   buitenlandsche_tijdschriften
# binnenlandsche_berichten   |   buitenlandsche_scheepvaart
# binnenlandsche_berichten   |   buitenlandsche_taken
# binnenlandsche_berichten   |   buitenlandsche_geldleeningen
# binnenlandsche_berichten   |   buitenlandsche_harde
# binnenlandsche_fondsen   |   buitenlandsche_fondsen
# binnenlandsche_fondsen   |   buitenlandsche_markten
# binnenlandsche_fondsen   |   buitenlandsche_orders
# binnenlandsche_fondsen   |   buitenlandsche_fondfen
# binnenlandsche_fondsen   |   buitenlandsche_commissien
# binnenlandsche_fondsen   |   buitenlandsche_effecten
# binnenlandsche_staatkunde   |   buitenlandsche_politiek
# binnenlandsche_staatkunde   |   buitenlandsche_belrekkingen
# binnenlandsche_staatkunde   |   buitenlandsche_agenten
# binnenlandsche_staatkunde   |   buitenlandsche_staatkunde
# binnenlandsche_staatkunde   |   buitenlandsche_aangelegenheden
# binnenlandsche_staatkunde   |   buitenlandsche_leeningen
# binnenlandsche_staatkunde   |   buitenlandsche_«aken
# binnenlandsche_staatkunde   |   buitenlandsche_vijanden
# binnenlandsche_staatkunde   |   buitenlandsche_aken
# binnenlandsche_staatkunde   |   buitenlandsche_geassocieerden
# binnenlandsche_staatkunde   |   buitenlandsche_zendingen
# binnenlandsche_staatkunde   |   buitenlandsche_voortbrengselen
# binnenlandsche_staatkunde   |   buitenlandsche_commissien
# binnenlandsche_staatkunde   |   buitenlandsche_betrekkingen
# binnenlandsche_staatkunde   |   buitenlandsche_bezittingen
# binnenlandsche_staatkunde   |   buitenlandsche_taken
# binnenlandsche_staatkunde   |   buitenlandsche_markten
# binnenlandsche_staatkunde   |   buitenlandsche_gezanten
# binnenlandsche_staatkunde   |   buitenlandsche_ministers
# binnenlandsche_staatkunde   |   buitenlandsche_zeevaart
# binnenlandsche_staatkunde   |   buitenlandsche_mogendheden
# binnenlandsche_staatkunde   |   buitenlandsche_ziken
# binnenlandsche_rekening   |   buitenlandsche_fondsen
# binnenlandsche_rekening   |   buitenlandsche_orders
# binnenlandsche_rekening   |   buitenlandsche_markten
# binnenlandsche_rekening   |   buitenlandsche_fondfen
# binnenlandsche_rekening   |   buitenlandsche_commissien
# binnenlandsche_rekening   |   buitenlandsche_verzendingen
# binnenlandsche_rekening   |   buitenlandsche_verzending
# binnenlandsche_rekening   |   buitenlandsche_leeningen
# binnenlandsche_turf   |   buitenlandsche_commissien
# binnenlandsche_turf   |   buitenlandsche_geassocieerden
# binnenlandsche_turf   |   buitenlandsche_«aken
# binnenlandsche_turf   |   buitenlandsche_harde
# binnenlandsche_turf   |   buitenlandsche_belrekkingen
# binnenlandsche_turf   |   buitenlandsche_verzending
# binnenlandsche_turf   |   buitenlandsche_voortbrengselen
# binnenlandsche_turf   |   buitenlandsche_tijdschriften
# binnenlandsche_turf   |   buitenlandsche_produkten
# binnenlandsche_turf   |   buitenlandsche_politiek
# binnenlandsche_turf   |   buitenlandsche_zendingen
# binnenlandsche_turf   |   buitenlandsche_bieren
# binnenlandsche_turf   |   buitenlandsche_agenten
# binnenlandsche_turf   |   buitenlandsche_steenkolen
# binnenlandsche_turf   |   buitenlandsche_leeningen
# binnenlandsche_turf   |   buitenlandsche_likeuren
# binnenlandsche_turf   |   buitenlandsche_verzendingen
# binnenlandsche_turf   |   buitenlandsche_aken
# binnenlandsche_turf   |   buitenlandsche_taken
# binnenlandsche_turf   |   buitenlandsche_orders
# binnenlandsche_turf   |   buitenlandsche_zeep
# binnenlandsche_turf   |   buitenlandsche_rerigten
# binnenlandsche_turf   |   buitenlandsche_zeevaart
# binnenlandsche_commissien   |   buitenlandsche_orders
# binnenlandsche_commissien   |   buitenlandsche_commissien
# binnenlandsche_commissien   |   buitenlandsche_fondsen
# binnenlandsche_commissien   |   buitenlandsche_voortbrengselen
# binnenlandsche_commissien   |   buitenlandsche_«aken
# binnenlandsche_commissien   |   buitenlandsche_geassocieerden
# binnenlandsche_commissien   |   buitenlandsche_harde
# binnenlandsche_commissien   |   buitenlandsche_fondfen
# binnenlandsche_commissien   |   buitenlandsche_produkten
# binnenlandsche_commissien   |   buitenlandsche_markten
# binnenlandsche_commissien   |   buitenlandsche_aken
# binnenlandsche_commissien   |   buitenlandsche_leeningen
# binnenlandsche_commissien   |   buitenlandsche_verzending
# binnenlandsche_commissien   |   buitenlandsche_belrekkingen
# binnenlandsche_commissien   |   buitenlandsche_politiek
# binnenlandsche_commissien   |   buitenlandsche_geleerden
# binnenlandsche_commissien   |   buitenlandsche_effecten
# binnenlandsche_commissien   |   buitenlandsche_taken
# binnenlandsche_commissien   |   buitenlandsche_zendingen
#
# 1835
# binnenlandsche_zaten   |   buitenlandsche_taken
# binnenlandsche_zaten   |   buitenlandsche_ziken
# binnenlandsche_zaten   |   buitenlandsche_aken
# binnenlandsche_zaten   |   buitenlandsche_zaken
# binnenlandsche_zaten   |   buitenlandsche_«aken
# binnenlandsche_zaten   |   buitenlandsche_zakeu
# binnenlandsche_zaken   |   buitenlandsche_zaken
# binnenlandsche_zaken   |   buitenlandsche_zakeu
# binnenlandsche_zaken   |   buitenlandsche_aken
# binnenlandsche_zaken   |   buitenlandsche_taken
# binnenlandsche_zaken   |   buitenlandsche_ziken
# binnenlandsche_zaken   |   buitenlandsche_«aken
# binnenlandsche_zaken   |   buitenlandsche_aangelegenheden
# binnenlandsche_zsken   |   buitenlandsche_taken
# binnenlandsche_zsken   |   buitenlandsche_aken
# binnenlandsche_zsken   |   buitenlandsche_ziken
# binnenlandsche_zsken   |   buitenlandsche_zakeu
# binnenlandsche_zsken   |   buitenlandsche_zaken
# binnenlandsche_zsken   |   buitenlandsche_«aken
# binnenlandsche_zsken   |   buitenlandsche_aangelegenheden
# binnenlandsche_zsken   |   buitenlandsche_politiek
# binnenlandsche_zakeu   |   buitenlandsche_aken
# binnenlandsche_zakeu   |   buitenlandsche_«aken
# binnenlandsche_zakeu   |   buitenlandsche_ziken
# binnenlandsche_zakeu   |   buitenlandsche_zakeu
# binnenlandsche_zakeu   |   buitenlandsche_taken
# binnenlandsche_zakeu   |   buitenlandsche_zaken
# binnenlandsche_ziken   |   buitenlandsche_ziken
# binnenlandsche_ziken   |   buitenlandsche_aken
# binnenlandsche_ziken   |   buitenlandsche_taken
# binnenlandsche_ziken   |   buitenlandsche_zaken
# binnenlandsche_ziken   |   buitenlandsche_zakeu
# binnenlandsche_ziken   |   buitenlandsche_«aken
# binnenlandsche_ziken   |   buitenlandsche_agenten
# binnenlandsche_ziken   |   buitenlandsche_aangelegenheden
# binnenlandsche_onlusten   |   buitenlandsche_vijanden
# binnenlandsche_onlusten   |   buitenlandsche_staatkunde
# binnenlandsche_onlusten   |   buitenlandsche_handel
# binnenlandsche_onlusten   |   buitenlandsche_politiek
# binnenlandsche_paspoorten   |   buitenlandsche_paspoorten
# binnenlandsche_paspoorten   |   buitenlandsche_zeep
# binnenlandsche_paspoorten   |   buitenlandsche_producten
# binnenlandsche_paspoorten   |   buitenlandsche_bieren
# binnenlandsche_paspoorten   |   buitenlandsche_granen
# binnenlandsche_paspoorten   |   buitenlandsche_zeevaart
# binnenlandsche_paspoorten   |   buitenlandsche_verzending
# binnenlandsche_paspoorten   |   buitenlandsche_orders
# binnenlandsche_berigten   |   buitenlandsche_berigten
# binnenlandsche_effecten   |   buitenlandsche_effecten
# binnenlandsche_effecten   |   buitenlandsche_effekten
# binnenlandsche_effecten   |   buitenlandsche_fondfen
# binnenlandsche_effecten   |   buitenlandsche_prijshoudende
# binnenlandsche_effecten   |   buitenlandsche_fondsen
# binnenlandsche_zaleen   |   buitenlandsche_aken
# binnenlandsche_zaleen   |   buitenlandsche_taken
# binnenlandsche_zaleen   |   buitenlandsche_ziken
# binnenlandsche_zaleen   |   buitenlandsche_«aken
# binnenlandsche_zaleen   |   buitenlandsche_zakeu
# binnenlandsche_zaleen   |   buitenlandsche_zaken
# binnenlandsche_zaleen   |   buitenlandsche_politiek
# binnenlandsche_zaleen   |   buitenlandsche_agenten
# binnenlandsche_zaleen   |   buitenlandsche_belrekkingen
# binnenlandsche_negotiatien   |   buitenlandsche_harde
# binnenlandsche_negotiatien   |   buitenlandsche_effekten
# binnenlandsche_negotiatien   |   buitenlandsche_beurt
# binnenlandsche_negotiatien   |   buitenlandsche_bieren
# binnenlandsche_negotiatien   |   buitenlandsche_prijshoudende
# binnenlandsche_negotiatien   |   buitenlandsche_paspoorten
# binnenlandsche_negotiatien   |   buitenlandsche_zeep
# binnenlandsche_negotiatien   |   buitenlandsche_rerigten
# binnenlandsche_negotiatien   |   buitenlandsche_effecten
# binnenlandsche_negotiatien   |   buitenlandsche_commissien
# binnenlandsche_negotiatien   |   buitenlandsche_fondfen
# binnenlandsche_negotiatien   |   buitenlandsche_wijn
# binnenlandsche_negotiatien   |   buitenlandsche_verzending
# binnenlandsche_negotiatien   |   buitenlandsche_geldleeningen
# binnenlandsche_negotiatien   |   buitenlandsche_steenkolen
# binnenlandsche_zake   |   buitenlandsche_ziken
# binnenlandsche_zake   |   buitenlandsche_taken
# binnenlandsche_zake   |   buitenlandsche_aken
# binnenlandsche_zake   |   buitenlandsche_«aken
# binnenlandsche_zake   |   buitenlandsche_zakeu
# binnenlandsche_zake   |   buitenlandsche_zaken
# binnenlandsche_zake   |   buitenlandsche_belrekkingen
# binnenlandsche_zake   |   buitenlandsche_agenten
# binnenlandsche_vaart   |   buitenlandsche_producten
# binnenlandsche_vaart   |   buitenlandsche_bieren
# binnenlandsche_vaart   |   buitenlandsche_zeep
# binnenlandsche_vaart   |   buitenlandsche_brandewijn
# binnenlandsche_vaart   |   buitenlandsche_steenkolen
# binnenlandsche_vaart   |   buitenlandsche_granen
# binnenlandsche_vaart   |   buitenlandsche_handel
# binnenlandsche_vaart   |   buitenlandsche_produkten
# binnenlandsche_vaart   |   buitenlandsche_harde
# binnenlandsche_vaart   |   buitenlandsche_paspoorten
# binnenlandsche_vaart   |   buitenlandsche_wijn
# binnenlandsche_vaart   |   buitenlandsche_verzending
# binnenlandsche_vaart   |   buitenlandsche_likeuren
# binnenlandsche_vaart   |   buitenlandsche_zeevaart
# binnenlandsche_zakea   |   buitenlandsche_ziken
# binnenlandsche_zakea   |   buitenlandsche_taken
# binnenlandsche_zakea   |   buitenlandsche_aken
# binnenlandsche_zakea   |   buitenlandsche_«aken
# binnenlandsche_zakea   |   buitenlandsche_zakeu
# binnenlandsche_zakea   |   buitenlandsche_zaken
# binnenlandsche_zakea   |   buitenlandsche_agenten
# binnenlandsche_zakea   |   buitenlandsche_belrekkingen
# binnenlandsche_zakea   |   buitenlandsche_hoven
# binnenlandsche_zakenen   |   buitenlandsche_taken
# binnenlandsche_zakenen   |   buitenlandsche_ziken
# binnenlandsche_zakenen   |   buitenlandsche_aken
# binnenlandsche_zakenen   |   buitenlandsche_rerigten
# binnenlandsche_zakenen   |   buitenlandsche_«aken
# binnenlandsche_zakenen   |   buitenlandsche_bieren
# binnenlandsche_zakenen   |   buitenlandsche_harde
# binnenlandsche_zakenen   |   buitenlandsche_paspoorten
# binnenlandsche_zakenen   |   buitenlandsche_produkten
# binnenlandsche_za   |   buitenlandsche_taken
# binnenlandsche_za   |   buitenlandsche_ziken
# binnenlandsche_za   |   buitenlandsche_aken
# binnenlandsche_za   |   buitenlandsche_«aken
# binnenlandsche_za   |   buitenlandsche_zakeu
# binnenlandsche_za   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_ziken
# binnenlandsche_aken   |   buitenlandsche_aken
# binnenlandsche_aken   |   buitenlandsche_taken
# binnenlandsche_aken   |   buitenlandsche_zaken
# binnenlandsche_aken   |   buitenlandsche_zakeu
# binnenlandsche_aken   |   buitenlandsche_«aken
# binnenlandsche_welvaart   |   buitenlandsche_handel
# binnenlandsche_welvaart   |   buitenlandsche_mededinging
# binnenlandsche_welvaart   |   buitenlandsche_bezittingen
# binnenlandsche_znken   |   buitenlandsche_taken
# binnenlandsche_znken   |   buitenlandsche_aken
# binnenlandsche_znken   |   buitenlandsche_ziken
# binnenlandsche_znken   |   buitenlandsche_zakeu
# binnenlandsche_znken   |   buitenlandsche_zaken
# binnenlandsche_znken   |   buitenlandsche_«aken
# binnenlandsche_znken   |   buitenlandsche_aangelegenheden
# binnenlandsche_bieren   |   buitenlandsche_bieren
# binnenlandsche_bieren   |   buitenlandsche_producten
# binnenlandsche_bieren   |   buitenlandsche_steenkolen
# binnenlandsche_bieren   |   buitenlandsche_harde
# binnenlandsche_bieren   |   buitenlandsche_zeep
# binnenlandsche_bieren   |   buitenlandsche_produkten
# binnenlandsche_bieren   |   buitenlandsche_brandewijn
# binnenlandsche_bieren   |   buitenlandsche_wijn
# binnenlandsche_bieren   |   buitenlandsche_likeuren
# binnenlandsche_bieren   |   buitenlandsche_verzending
# binnenlandsche_bieren   |   buitenlandsche_granen
# binnenlandsche_bieren   |   buitenlandsche_beurt
# binnenlandsche_bieren   |   buitenlandsche_voorkomende
# binnenlandsche_bieren   |   buitenlandsche_paspoorten
# binnenlandsche_bieren   |   buitenlandsche_handel
# binnenlandsche_bieren   |   buitenlandsche_fondfen
# binnenlandsche_bieren   |   buitenlandsche_voortbrengselen
# binnenlandsche_bieren   |   buitenlandsche_markten
# binnenlandsche_steenkolen   |   buitenlandsche_bieren
# binnenlandsche_steenkolen   |   buitenlandsche_producten
# binnenlandsche_steenkolen   |   buitenlandsche_zeep
# binnenlandsche_steenkolen   |   buitenlandsche_harde
# binnenlandsche_steenkolen   |   buitenlandsche_brandewijn
# binnenlandsche_steenkolen   |   buitenlandsche_steenkolen
# binnenlandsche_steenkolen   |   buitenlandsche_produkten
# binnenlandsche_steenkolen   |   buitenlandsche_wijn
# binnenlandsche_steenkolen   |   buitenlandsche_verzending
# binnenlandsche_steenkolen   |   buitenlandsche_likeuren
# binnenlandsche_steenkolen   |   buitenlandsche_granen
# binnenlandsche_steenkolen   |   buitenlandsche_fondfen
# binnenlandsche_steenkolen   |   buitenlandsche_handel
# binnenlandsche_steenkolen   |   buitenlandsche_paspoorten
# binnenlandsche_steenkolen   |   buitenlandsche_zeevaart
# binnenlandsche_steenkolen   |   buitenlandsche_markten
# binnenlandsche_steenkolen   |   buitenlandsche_beurt
# binnenlandsche_steenkolen   |   buitenlandsche_voortbrengselen
# binnenlandsche_steenkolen   |   buitenlandsche_orders
# binnenlandsche_steenkolen   |   buitenlandsche_verzendingen
# binnenlandsche_circulatie   |   buitenlandsche_harde
# binnenlandsche_circulatie   |   buitenlandsche_geassocieerden
# binnenlandsche_circulatie   |   buitenlandsche_commissien
# binnenlandsche_circulatie   |   buitenlandsche_handel
# binnenlandsche_circulatie   |   buitenlandsche_belrekkingen
# binnenlandsche_circulatie   |   buitenlandsche_bieren
# binnenlandsche_circulatie   |   buitenlandsche_verzending
# binnenlandsche_circulatie   |   buitenlandsche_paspoorten
# binnenlandsche_circulatie   |   buitenlandsche_steenkolen
# binnenlandsche_circulatie   |   buitenlandsche_voortbrengselen
# binnenlandsche_circulatie   |   buitenlandsche_agenten
# binnenlandsche_circulatie   |   buitenlandsche_zeep
# binnenlandsche_scheepvaart   |   buitenlandsche_granen
# binnenlandsche_scheepvaart   |   buitenlandsche_producten
# binnenlandsche_scheepvaart   |   buitenlandsche_handel
# binnenlandsche_scheepvaart   |   buitenlandsche_zeep
# binnenlandsche_scheepvaart   |   buitenlandsche_markten
# binnenlandsche_scheepvaart   |   buitenlandsche_bieren
# binnenlandsche_scheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_scheepvaart   |   buitenlandsche_orders
# binnenlandsche_scheepvaart   |   buitenlandsche_fabrijken
# binnenlandsche_scheepvaart   |   buitenlandsche_fondsen
# binnenlandsche_scheepvaart   |   buitenlandsche_zendingen
# binnenlandsche_scheepvaart   |   buitenlandsche_verzending
# binnenlandsche_scheepvaart   |   buitenlandsche_mededinging
# binnenlandsche_nijverheid   |   buitenlandsche_mededinging
# binnenlandsche_nijverheid   |   buitenlandsche_handel
# binnenlandsche_nijverheid   |   buitenlandsche_granen
# binnenlandsche_nijverheid   |   buitenlandsche_markten
# binnenlandsche_nijverheid   |   buitenlandsche_fabrijken
# binnenlandsche_nijverheid   |   buitenlandsche_schuldeischers
# binnenlandsche_nijverheid   |   buitenlandsche_vijanden
# binnenlandsche_nijverheid   |   buitenlandsche_producten
# binnenlandsche_nijverheid   |   buitenlandsche_betrekkingen
# binnenlandsche_nijverheid   |   buitenlandsche_fondsen
# binnenlandsche_nijverheid   |   buitenlandsche_staatkunde
# binnenlandsche_effekten   |   buitenlandsche_effekten
# binnenlandsche_effekten   |   buitenlandsche_prijshoudende
# binnenlandsche_effekten   |   buitenlandsche_harde
# binnenlandsche_consumtie   |   buitenlandsche_granen
# binnenlandsche_consumtie   |   buitenlandsche_handel
# binnenlandsche_consumtie   |   buitenlandsche_verzending
# binnenlandsche_consumtie   |   buitenlandsche_orders
# binnenlandsche_consumtie   |   buitenlandsche_zeep
# binnenlandsche_consumtie   |   buitenlandsche_brandewijn
# binnenlandsche_consumtie   |   buitenlandsche_markten
# binnenlandsche_consumtie   |   buitenlandsche_verzendingen
# binnenlandsche_consumtie   |   buitenlandsche_bieren
# binnenlandsche_consumtie   |   buitenlandsche_producten
# binnenlandsche_consumtie   |   buitenlandsche_harde
# binnenlandsche_consumtie   |   buitenlandsche_mededinging
# binnenlandsche_consumtie   |   buitenlandsche_voortbrengselen
# binnenlandsche_consumtie   |   buitenlandsche_zeevaart
# binnenlandsche_consumtie   |   buitenlandsche_wijn
# binnenlandsche_consumtie   |   buitenlandsche_fondfen
# binnenlandsche_consumtie   |   buitenlandsche_commissien
# binnenlandsche_consumtie   |   buitenlandsche_paspoorten
# binnenlandsche_consumtie   |   buitenlandsche_likeuren
# binnenlandsche_zeep   |   buitenlandsche_bieren
# binnenlandsche_zeep   |   buitenlandsche_steenkolen
# binnenlandsche_zeep   |   buitenlandsche_producten
# binnenlandsche_zeep   |   buitenlandsche_harde
# binnenlandsche_zeep   |   buitenlandsche_zeep
# binnenlandsche_zeep   |   buitenlandsche_produkten
# binnenlandsche_zeep   |   buitenlandsche_likeuren
# binnenlandsche_zeep   |   buitenlandsche_brandewijn
# binnenlandsche_zeep   |   buitenlandsche_geldleeningen
# binnenlandsche_zeep   |   buitenlandsche_wijn
# binnenlandsche_zeep   |   buitenlandsche_verzending
# binnenlandsche_zeep   |   buitenlandsche_voorkomende
# binnenlandsche_zeep   |   buitenlandsche_paspoorten
# binnenlandsche_zeep   |   buitenlandsche_voortbrengselen
# binnenlandsche_zeep   |   buitenlandsche_beurt
# binnenlandsche_fcheepvaart   |   buitenlandsche_produkten
# binnenlandsche_fcheepvaart   |   buitenlandsche_harde
# binnenlandsche_fcheepvaart   |   buitenlandsche_bieren
# binnenlandsche_fcheepvaart   |   buitenlandsche_verzending
# binnenlandsche_fcheepvaart   |   buitenlandsche_wijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_producten
# binnenlandsche_fcheepvaart   |   buitenlandsche_paspoorten
# binnenlandsche_fcheepvaart   |   buitenlandsche_brandewijn
# binnenlandsche_fcheepvaart   |   buitenlandsche_verzendingen
# binnenlandsche_fcheepvaart   |   buitenlandsche_handel
# ...
# binnenlandsche_toestanden   |   buitenlandsche_mogendheden
# binnenlandsche_toestanden   |   buitenlandsche_vertegenwoordigers
# binnenlandsche_toestanden   |   buitenlandsche_schuldeischers
# binnenlandsche_toestanden   |   buitenlandsche_concurrentie
# binnenlandsche_toestanden   |   buitenlandsche_berichten
# binnenlandsche_toestanden   |   buitenlandsche_bladen
# binnenlandsche_toestanden   |   buitenlandsche_schuld
# binnenlandsche_toestanden   |   buitenlandsche_dagbladpers
# binnenlandsche_toestanden   |   buitenlandsche_markten
# binnenlandsche_toestanden   |   buitenlandsche_vereenigingen
# binnenlandsche_toestanden   |   buitenlandsche_consuls
# binnenlandsche_toestanden   |   buitenlandsche_staatsfinanciën
# binnenlandsche_toestanden   |   buitenlandsche_staatsfondsen
# binnenlandsche_toestanden   |   buitenlandsche_gouvernementen
# binnenlandsche_toestanden   |   buitenlandsche_koersen
# binnenlandsche_toestanden   |   buitenlandsche_belrekkingen
# binnenlandsche_toestanden   |   buitenlandsche_gezanten
# binnenlandsche_toestanden   |   buitenlandsche_gasten
# binnenlandsche_industrie   |   buitenlandsche_mededinging
# binnenlandsche_industrie   |   buitenlandsche_concurrentie
# binnenlandsche_industrie   |   buitenlandsche_schuldeischers
# binnenlandsche_industrie   |   buitenlandsche_maatschappijen
# binnenlandsche_industrie   |   buitenlandsche_markten
# binnenlandsche_industrie   |   buitenlandsche_regeeringen
# binnenlandsche_industrie   |   buitenlandsche_fabrikanten
# binnenlandsche_industrie   |   buitenlandsche_gasten
# binnenlandsche_industrie   |   buitenlandsche_producten
# binnenlandsche_industrie   |   buitenlandsche_vereenigingen
# binnenlandsche_industrie   |   buitenlandsche_inzenders
# binnenlandsche_staatsfondsen   |   buitenlandsche_soorten
# binnenlandsche_staatsfondsen   |   buitenlandsche_markt
# binnenlandsche_staatsfondsen   |   buitenlandsche_fondsenmarkt
# binnenlandsche_staatsfondsen   |   buitenlandsche_staatsfondsen
# binnenlandsche_staatsfondsen   |   buitenlandsche_fondsen
# binnenlandsche_staatsfondsen   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_staatsfondsen   |   buitenlandsche_koersen
# binnenlandsche_staatsfondsen   |   buitenlandsche_staatsleeningen
# binnenlandsche_staatsfondsen   |   buitenlandsche_merken
# binnenlandsche_staatsfondsen   |   buitenlandsche_leverde
# binnenlandsche_staatsfondsen   |   buitenlandsche_kooporders
# binnenlandsche_staatsfondsen   |   buitenlandsche_verkooporders
# binnenlandsche_staatsfondsen   |   buitenlandsche_meerendeels
# binnenlandsche_staatsfondsen   |   buitenlandsche_granen
# binnenlandsche_staatsfondsen   |   buitenlandsche_rekening
# binnenlandsche_staatsfondsen   |   buitenlandsche_noteeringen
# binnenlandsche_staatsfondsen   |   buitenlandsche_orders
# binnenlandsche_staatsfondsen   |   buitenlandsche_noteeren
# binnenlandsche_staatsfondsen   |   buitenlandsche_effecten
# binnenlandsche_staatsfondsen   |   buitenlandsche_wisselkoersen
# binnenlandsche_staatsfondsen   |   buitenlandsche_pet
# binnenlandsche_staatsfondsen   |   buitenlandsche_markten
# binnenlandsche_staatsfondsen   |   buitenlandsche_beurzen
# binnenlandsche_staatsfondsen   |   buitenlandsche_handelsberichten
# binnenlandsche_behoefte   |   buitenlandsche_orders
# binnenlandsche_behoefte   |   buitenlandsche_markten
# binnenlandsche_behoefte   |   buitenlandsche_rekening
# binnenlandsche_behoefte   |   buitenlandsche_noteeringen
# binnenlandsche_behoefte   |   buitenlandsche_koersen
# binnenlandsche_behoefte   |   buitenlandsche_voererwten
# binnenlandsche_behoefte   |   buitenlandsche_fondsenmarkt
# binnenlandsche_behoefte   |   buitenlandsche_soorten
# binnenlandsche_behoefte   |   buitenlandsche_fondfen
# binnenlandsche_behoefte   |   buitenlandsche_verkooporders
# binnenlandsche_behoefte   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_behoefte   |   buitenlandsche_granen
# binnenlandsche_behoefte   |   buitenlandsche_kooporders
# binnenlandsche_behoefte   |   buitenlandsche_verzending
# binnenlandsche_behoefte   |   buitenlandsche_handel
# binnenlandsche_behoefte   |   buitenlandsche_honig
# binnenlandsche_behoefte   |   buitenlandsche_verkoopen
# binnenlandsche_behoefte   |   buitenlandsche_inzenders
# binnenlandsche_behoefte   |   buitenlandsche_merken
# binnenlandsche_behoefte   |   buitenlandsche_kooplieden
# binnenlandsche_behoefte   |   buitenlandsche_zeep
# binnenlandsche_behoefte   |   buitenlandsche_staatsfondsen
# binnenlandsche_behoefte   |   buitenlandsche_aankoopen
# binnenlandsche_behoefte   |   buitenlandsche_wisselportefeuille
# binnenlandsche_behoefte   |   buitenlandsche_markt
# binnenlandsche_behoefte   |   buitenlandsche_fondsen
# binnenlandsche_behoefte   |   buitenlandsche_verzendingen
# binnenlandsche_behoefte   |   buitenlandsche_fabrikanten
# binnenlandsche_behoefte   |   buitenlandsche_effecten
# binnenlandsche_behoefte   |   buitenlandsche_noteeren
# binnenlandsche_behoefte   |   buitenlandsche_rogge
# binnenlandsche_behoefte   |   buitenlandsche_wissels
# binnenlandsche_behoefte   |   buitenlandsche_gasten
# binnenlandsche_behoefte   |   buitenlandsche_wisselkoersen
# binnenlandsche_behoefte   |   buitenlandsche_leverde
# binnenlandsche_behoefte   |   buitenlandsche_likeuren
# binnenlandsche_behoefte   |   buitenlandsche_bieren
# binnenlandsche_piasters   |   buitenlandsche_nrdamer
# binnenlandsche_piasters   |   buitenlandsche_1867
# binnenlandsche_piasters   |   buitenlandsche_buersberigten
# binnenlandsche_piasters   |   buitenlandsche_lijdingen
# binnenlandsche_piasters   |   buitenlandsche_studenten
# binnenlandsche_piasters   |   buitenlandsche_bankbiljetten
# binnenlandsche_piaster   |   buitenlandsche_bankbiljetten
# binnenlandsche_piaster   |   buitenlandsche_1867
# binnenlandsche_havens   |   buitenlandsche_havens
# binnenlandsche_havens   |   buitenlandsche_nieuws
# binnenlandsche_havens   |   buitenlandsche_handelsberichten
# binnenlandsche_nieuws   |   buitenlandsche_beursberigten
# binnenlandsche_nieuws   |   buitenlandsche_nieuws
# binnenlandsche_telegrammen   |   buitenlandsche_voer
# binnenlandsche_telegrammen   |   buitenlandsche_noteeren
# binnenlandsche_telegrammen   |   buitenlandsche_staatsfinanciën
# binnenlandsche_telegrammen   |   buitenlandsche_likeuren
# binnenlandsche_telegrammen   |   buitenlandsche_verkoopen
# binnenlandsche_telegrammen   |   buitenlandsche_houders
# binnenlandsche_telegrammen   |   buitenlandsche_inzenders
# binnenlandsche_telegrammen   |   buitenlandsche_portefeuille
# binnenlandsche_telegrammen   |   buitenlandsche_beleid
# binnenlandsche_telegrammen   |   buitenlandsche_handelscijfers
# binnenlandsche_telegrammen   |   buitenlandsche_perpetueele
# binnenlandsche_telegrammen   |   buitenlandsche_passen
# binnenlandsche_telegrammen   |   buitenlandsche_wisselportefeuille
# binnenlandsche_zalen   |   buitenlandsche_zakon
# binnenlandsche_zalen   |   buitenlandsche_zakeu
# binnenlandsche_zalen   |   buitenlandsche_aken
# binnenlandsche_zalen   |   buitenlandsche_«aken
# binnenlandsche_zalen   |   buitenlandsche_ziken
# binnenlandsche_zalen   |   buitenlandsche_zaken
# binnenlandsche_zalen   |   buitenlandsche_voer
# binnenlandsche_zalen   |   buitenlandsche_1867
# binnenlandsche_zalen   |   buitenlandsche_taken
# binnenlandsche_zalen   |   buitenlandsche_inzenders
# binnenlandsche_zalen   |   buitenlandsche_staatsfinanciën
# binnenlandsche_zalen   |   buitenlandsche_perpetueele
# binnenlandsche_ruwe   |   buitenlandsche_basterdsuiker
# binnenlandsche_ruwe   |   buitenlandsche_ruwe
# binnenlandsche_ruwe   |   buitenlandsche_bieren
# binnenlandsche_ruwe   |   buitenlandsche_harde
# binnenlandsche_basterdsuiker   |   buitenlandsche_basterdsuiker
# binnenlandsche_basterdsuiker   |   buitenlandsche_nrdamer
# binnenlandsche_basterdsuiker   |   buitenlandsche_perpetueele
# binnenlandsche_verdediging   |   buitenlandsche_zendingen
# binnenlandsche_verdediging   |   buitenlandsche_voer
# binnenlandsche_verdediging   |   buitenlandsche_inzenders
# binnenlandsche_tarief   |   buitenlandsche_perpetueele
# binnenlandsche_tarief   |   buitenlandsche_naamlooze
# binnenlandsche_honig   |   buitenlandsche_honig
# binnenlandsche_honig   |   buitenlandsche_ƒ36
# binnenlandsche_honig   |   buitenlandsche_soorten
# binnenlandsche_honig   |   buitenlandsche_staatsleeningen
# binnenlandsche_honig   |   buitenlandsche_staatsfondsen
# binnenlandsche_honig   |   buitenlandsche_prijshoudende
# binnenlandsche_honig   |   buitenlandsche_granen
# binnenlandsche_honig   |   buitenlandsche_fondsenmarkt
# binnenlandsche_wissels   |   buitenlandsche_wissels
# binnenlandsche_wissels   |   buitenlandsche_bankbiljetten
# binnenlandsche_wissels   |   buitenlandsche_aanvoeren
# binnenlandsche_wissels   |   buitenlandsche_pot
# binnenlandsche_wissels   |   buitenlandsche_handelscijfers
# binnenlandsche_wissels   |   buitenlandsche_pet
# binnenlandsche_perpetueele   |   buitenlandsche_perpetueele
# binnenlandsche_perpetueele   |   buitenlandsche_pot
# binnenlandsche_perpetueele   |   buitenlandsche_handelscijfers
# binnenlandsche_perpetueele   |   buitenlandsche_1867
# binnenlandsche_perpetueele   |   buitenlandsche_staatsfinanciën
# binnenlandsche_perpetueele   |   buitenlandsche_noteeren
# binnenlandsche_perpetueele   |   buitenlandsche_nrdamer
# binnenlandsche_perpetueele   |   buitenlandsche_pet
# binnenlandsche_perpetueele   |   buitenlandsche_buersberigten
# binnenlandsche_perpetueele   |   buitenlandsche_handelsberichten
# binnenlandsche_perpetueele   |   buitenlandsche_voer
# binnenlandsche_leening   |   buitenlandsche_leeningen
# binnenlandsche_leening   |   buitenlandsche_schuld
# binnenlandsche_leening   |   buitenlandsche_leening
# binnenlandsche_leening   |   buitenlandsche_bankiers
# binnenlandsche_leening   |   buitenlandsche_schuldbrieven
# binnenlandsche_leening   |   buitenlandsche_maatschappijen
# binnenlandsche_leening   |   buitenlandsche_fondsen
# binnenlandsche_leening   |   buitenlandsche_schuldeischers
# binnenlandsche_leening   |   buitenlandsche_wisselkoersen
# binnenlandsche_leening   |   buitenlandsche_effecten
# binnenlandsche_aanvoeren   |   buitenlandsche_aankoopen
# binnenlandsche_aanvoeren   |   buitenlandsche_noteeringen
# binnenlandsche_aanvoeren   |   buitenlandsche_verkoopen
# binnenlandsche_aanvoeren   |   buitenlandsche_markten
# binnenlandsche_aanvoeren   |   buitenlandsche_koersen
# binnenlandsche_aanvoeren   |   buitenlandsche_merken
# binnenlandsche_aanvoeren   |   buitenlandsche_orders
# binnenlandsche_aanvoeren   |   buitenlandsche_kooporders
# binnenlandsche_aanvoeren   |   buitenlandsche_rekening
# binnenlandsche_aanvoeren   |   buitenlandsche_soorten
# binnenlandsche_aanvoeren   |   buitenlandsche_verkooporders
# binnenlandsche_aanvoeren   |   buitenlandsche_staatsfondsen
# binnenlandsche_aanvoeren   |   buitenlandsche_granen
# binnenlandsche_aanvoeren   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_aanvoeren   |   buitenlandsche_wisselportefeuille
# binnenlandsche_aanvoeren   |   buitenlandsche_wisselkoersen
# binnenlandsche_aanvoeren   |   buitenlandsche_voererwten
# binnenlandsche_aanvoeren   |   buitenlandsche_staatsfinanciën
# binnenlandsche_aanvoeren   |   buitenlandsche_markt
# binnenlandsche_aanvoeren   |   buitenlandsche_handelscijfers
# binnenlandsche_aanvoeren   |   buitenlandsche_rogge
# binnenlandsche_aanvoeren   |   buitenlandsche_melasse
# binnenlandsche_aanvoeren   |   buitenlandsche_fondsenmarkt
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_soorten
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_staatsfondsen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_fondsenmarkt
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_kooporders
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_merken
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_koersen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_fondsen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_staatsleeningen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_markt
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_rekening
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_meerendeels
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_leverde
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_verkooporders
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_noteeringen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_pet
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_wisselkoersen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_orders
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_markten
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_noteeren
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_wissels
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_effecten
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_aankoopen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_granen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_fondfen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_prijshoudende
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_beurzen
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_voererwten
# binnenlandsche_spoorwegwaarden   |   buitenlandsche_leeningen
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_kooporders
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_fondsen
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_staatsfondsen
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_prijshoudende
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_soorten
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_fondsenmarkt
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_verkooporders
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_markt
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_effecten
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_rekening
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_staatsleeningen
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_merken
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_koersen
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_leverde
# binnenlandsche_spoorwegobligatiën   |   buitenlandsche_wissels
# binnenlandsche_1890   |   buitenlandsche_nrdamer
# binnenlandsche_1890   |   buitenlandsche_1867
# binnenlandsche_1890   |   buitenlandsche_perpetueele
# binnenlandsche_1890   |   buitenlandsche_basterdsuiker
# binnenlandsche_1890   |   buitenlandsche_honig
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_noteeren
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_verkoopen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_kooporders
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_verkooporders
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_pet
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_voer
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_staatsleeningen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_soorten
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_noteeringen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_koersen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_rekening
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_meerendeels
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_voererwten
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_staatsfondsenmarkt
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_perpetueele
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_merken
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_staatsfondsen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_fondsenmarkt
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_leverde
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_bankiers
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_markt
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_staatsfinanciën
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_portefeuille
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_pot
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_aankoopen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_wisselkoersen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_fondsen
# binnenlandsche_spoorwegfondsen   |   buitenlandsche_souvereinen

# %%
d = pd.DataFrame([[a for a,b,c,d in df], [b for a,b,c,d in df], [c for a,b,c,d in df], [d for a,b,c,d in df]]).T
d.columns = ['source', 'target', ' weight', 'year']
d['degree'] = 1
d
# Out:
#                               source                             target  \
# 0               binnenlandsche_zaten               buitenlandsche_ziken
# 1               binnenlandsche_zaten               buitenlandsche_taken
# 2               binnenlandsche_zaten               buitenlandsche_zaken
# 3               binnenlandsche_zaken               buitenlandsche_zaken
# 4               binnenlandsche_zaken               buitenlandsche_ziken
# 5               binnenlandsche_zaken               buitenlandsche_taken
# 6               binnenlandsche_zsken               buitenlandsche_taken
# 7               binnenlandsche_zsken               buitenlandsche_ziken
# 8               binnenlandsche_zsken               buitenlandsche_zaken
# 9               binnenlandsche_zsken               buitenlandsche_hoven
# 10              binnenlandsche_zakeu               buitenlandsche_ziken
# 11              binnenlandsche_zakeu               buitenlandsche_taken
# 12              binnenlandsche_zakeu               buitenlandsche_zaken
# 13              binnenlandsche_ziken               buitenlandsche_ziken
# 14              binnenlandsche_ziken               buitenlandsche_zaken
# 15              binnenlandsche_ziken               buitenlandsche_taken
# 16           binnenlandsche_onlusten            buitenlandsche_zeevaart
# 17         binnenlandsche_paspoorten            buitenlandsche_zeevaart
# 18         binnenlandsche_paspoorten              buitenlandsche_bieren
# 19         binnenlandsche_paspoorten          buitenlandsche_paspoorten
# 20         binnenlandsche_paspoorten           buitenlandsche_producten
# 21         binnenlandsche_paspoorten                buitenlandsche_zeep
# 22         binnenlandsche_paspoorten               buitenlandsche_harde
# 23         binnenlandsche_paspoorten             buitenlandsche_fondsen
# 24         binnenlandsche_paspoorten              buitenlandsche_handel
# 25           binnenlandsche_berigten            buitenlandsche_berigten
# 26           binnenlandsche_berigten            buitenlandsche_rerigten
# 27           binnenlandsche_effecten            buitenlandsche_effecten
# 28           binnenlandsche_effecten                buitenlandsche_zeep
# 29           binnenlandsche_effecten              buitenlandsche_bieren
# ...                              ...                                ...
# 6979             binnenlandsche_1890       buitenlandsche_basterdsuiker
# 6980             binnenlandsche_1890               buitenlandsche_honig
# 6981  binnenlandsche_spoorwegfondsen            buitenlandsche_noteeren
# 6982  binnenlandsche_spoorwegfondsen           buitenlandsche_verkoopen
# 6983  binnenlandsche_spoorwegfondsen          buitenlandsche_kooporders
# 6984  binnenlandsche_spoorwegfondsen       buitenlandsche_verkooporders
# 6985  binnenlandsche_spoorwegfondsen                 buitenlandsche_pet
# 6986  binnenlandsche_spoorwegfondsen                buitenlandsche_voer
# 6987  binnenlandsche_spoorwegfondsen     buitenlandsche_staatsleeningen
# 6988  binnenlandsche_spoorwegfondsen             buitenlandsche_soorten
# 6989  binnenlandsche_spoorwegfondsen         buitenlandsche_noteeringen
# 6990  binnenlandsche_spoorwegfondsen             buitenlandsche_koersen
# 6991  binnenlandsche_spoorwegfondsen            buitenlandsche_rekening
# 6992  binnenlandsche_spoorwegfondsen         buitenlandsche_meerendeels
# 6993  binnenlandsche_spoorwegfondsen          buitenlandsche_voererwten
# 6994  binnenlandsche_spoorwegfondsen  buitenlandsche_staatsfondsenmarkt
# 6995  binnenlandsche_spoorwegfondsen         buitenlandsche_perpetueele
# 6996  binnenlandsche_spoorwegfondsen              buitenlandsche_merken
# 6997  binnenlandsche_spoorwegfondsen       buitenlandsche_staatsfondsen
# 6998  binnenlandsche_spoorwegfondsen        buitenlandsche_fondsenmarkt
# 6999  binnenlandsche_spoorwegfondsen             buitenlandsche_leverde
# 7000  binnenlandsche_spoorwegfondsen            buitenlandsche_bankiers
# 7001  binnenlandsche_spoorwegfondsen               buitenlandsche_markt
# 7002  binnenlandsche_spoorwegfondsen     buitenlandsche_staatsfinanciën
# 7003  binnenlandsche_spoorwegfondsen        buitenlandsche_portefeuille
# 7004  binnenlandsche_spoorwegfondsen                 buitenlandsche_pot
# 7005  binnenlandsche_spoorwegfondsen           buitenlandsche_aankoopen
# 7006  binnenlandsche_spoorwegfondsen       buitenlandsche_wisselkoersen
# 7007  binnenlandsche_spoorwegfondsen             buitenlandsche_fondsen
# 7008  binnenlandsche_spoorwegfondsen         buitenlandsche_souvereinen
#
#         weight  year  degree
# 0     0.713831  1815       1
# 1     0.685393  1815       1
# 2     0.615847  1815       1
# 3     0.789546  1815       1
# 4     0.627454  1815       1
# 5      0.58853  1815       1
# 6     0.726509  1815       1
# 7      0.72074  1815       1
# 8     0.705373  1815       1
# 9     0.416598  1815       1
# 10    0.695034  1815       1
# 11    0.632828  1815       1
# 12    0.604243  1815       1
# 13     0.75933  1815       1
# 14    0.717081  1815       1
# 15    0.694747  1815       1
# 16    0.442629  1815       1
# 17    0.520812  1815       1
# 18    0.509157  1815       1
# 19    0.500093  1815       1
# 20    0.486482  1815       1
# 21    0.483505  1815       1
# 22    0.467562  1815       1
# 23    0.456696  1815       1
# 24    0.426731  1815       1
# 25    0.539412  1815       1
# 26    0.429765  1815       1
# 27    0.582072  1815       1
# 28    0.545318  1815       1
# 29    0.515415  1815       1
# ...        ...   ...     ...
# 6979  0.443139  1905       1
# 6980  0.435556  1905       1
# 6981   0.57875  1905       1
# 6982  0.576998  1905       1
# 6983  0.567703  1905       1
# 6984  0.556741  1905       1
# 6985  0.544072  1905       1
# 6986  0.543892  1905       1
# 6987  0.533605  1905       1
# 6988  0.528229  1905       1
# 6989  0.523742  1905       1
# 6990  0.513835  1905       1
# 6991  0.484839  1905       1
# 6992  0.484387  1905       1
# 6993  0.483332  1905       1
# 6994  0.479829  1905       1
# 6995  0.472445  1905       1
# 6996  0.471268  1905       1
# 6997  0.465608  1905       1
# 6998  0.460749  1905       1
# 6999  0.457484  1905       1
# 7000  0.437467  1905       1
# 7001  0.435971  1905       1
# 7002  0.435415  1905       1
# 7003   0.42869  1905       1
# 7004  0.421864  1905       1
# 7005  0.420476  1905       1
# 7006   0.42046  1905       1
# 7007  0.408322  1905       1
# 7008  0.401352  1905       1
#
# [7009 rows x 5 columns]

# %%
os.chdir("C://Users//Ruben//Documents//GitHub//TheForeign//Visualizations//CH2//source-files")
d.to_csv('binnenlandsche_most_similar_bigrams.csv', index=False)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
def PlotEnt(year):
    dt = d[d['year'] == year]

    B = nx.Graph()

    B.add_nodes_from(list(set(dt['source'])), bipartite=0)
    B.add_nodes_from(list(set(dt['target'])), bipartite=1)

    dt = dt.reset_index(drop=True)
    list_edges = []
    for c,i in enumerate(dt['source']):
        s = i
        t = dt['target'][c]
        list_edges.append((s,t))

    B.add_edges_from(list_edges)

    # Separate by group
    l, r = nx.bipartite.sets(B)
    pos = {}

    # Update position for node from each group
    pos.update((node, (1, index)) for index, node in enumerate(l))
    pos.update((node, (2, index)) for index, node in enumerate(r))

    plt.figure(3,figsize=(6,12)) 

    #colors = range(len(list_edges))


    nx.draw(B, 
            with_labels = True, 
            node_size = 10, 
            font_size = 8,
            edge_color = "lightsteelblue", 
            #edge_cmap = plt.get_cmap('Blues'),
            node_color = "lightsteelblue",
            pos = pos)
    
    plt.show()
    plt.tight_layout()

# %%
PlotEnt(1855)
