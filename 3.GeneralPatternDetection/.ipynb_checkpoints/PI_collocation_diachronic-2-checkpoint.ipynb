# %%
import os, re, glob, pandas as pd, math, random

# %%
os.chdir("D://Scriptie//Data//lines//cleaned")
list_txt = glob.glob('*.txt')
list_txt = [f for f in list_txt if f[5:12] == "cleaned"]

# %%
def get_context(list_of_lines, word1):
    lines = [l for l in list_of_lines if word1 in l]
    
    output_lines = list()
    
    for el in lines:
        line_tok = el.split(" ")
        positions = [idx for idx, s in enumerate(line_tok) if word1 in s]
            
        for pos in positions:
            p = int(pos)
            s = p - 24
            e = p + 24

            if s < 0:
                s = 0
            if e > (len(line_tok) - 1):
                e = (len(line_tok) - 1)

            selection = " ".join(line_tok[s:e])
            output_lines.append(selection)
            
    return output_lines

# %%
# log [probability(number of times both words appears in a document together)/probability(word1)*probability(word2)]

def file_len(fname):
    with open(fname, encoding = 'utf-8') as f:
        for i, l in enumerate(f):
            pass
    return i + 1

def pmi_year(year, word1, word2):
    fn = [f for f in list_txt if int(f[0:4]) == year][0]
    

    filesize = int(os.stat(fn).st_size) / 1000000
    filelen = file_len(fn)
    
    
    if filesize > 100:
        samplesize = round(100 * filelen / filesize)
        with open(fn, encoding = 'utf-8') as f:
            lines_year = random.sample(f.read().split('\n'),samplesize)    
    
    else:
        with open(fn, encoding = 'utf-8') as f:
            lines_year = f.read().split('\n')
    
    n_w1 = len([line for line in lines_year if word1 in line]) / len(lines_year)
    n_w2 = len([line for line in lines_year if word2 in line]) / len(lines_year)
    
    lines_selection = get_context(lines_year, word1)
    n_w1_w2 = len([line for line in lines_selection if word2 in line]) / len(lines_year)
    print(str(year) + " | " + word1 + ' and ' + word2 + ' occur ' + str(len([line for line in lines_selection if word2 in line])) + ' times together in window')
    
    if n_w1 == 0:
        col = 0
        
        
    if n_w2 == 0:
        col = 0
        
    if n_w1_w2 == 0:
        col = 0
    
    else:
        col = math.log(n_w1_w2 / (n_w1 * n_w2))
    return col

def dpmi(start_year, end_year, word1, word2):
    list_pmi = list()
    
    for year in range(start_year,(end_year + 1)):
        list_pmi.append(pmi_year(year, word1, word2))
        
    df = pd.DataFrame(list_pmi, columns = ['pmi'])
    
    df['year'] = list(range(start_year,(end_year+1)))
    
    return df

# %%
df = dpmi(1855, 1914, 'buitenland', 'groote')
w = df.plot.line(x='year', y='pmi')
# Out:
# 1855 | buitenland and groote occur 203 times together in window
# 1856 | buitenland and groote occur 237 times together in window
# 1857 | buitenland and groote occur 219 times together in window
# 1858 | buitenland and groote occur 250 times together in window
# 1859 | buitenland and groote occur 276 times together in window
# 1860 | buitenland and groote occur 260 times together in window
# 1861 | buitenland and groote occur 277 times together in window
# 1862 | buitenland and groote occur 247 times together in window
# 1863 | buitenland and groote occur 281 times together in window
# 1864 | buitenland and groote occur 280 times together in window
# 1865 | buitenland and groote occur 217 times together in window
# 1866 | buitenland and groote occur 264 times together in window
# 1867 | buitenland and groote occur 341 times together in window
# 1868 | buitenland and groote occur 311 times together in window
# 1869 | buitenland and groote occur 295 times together in window
# 1870 | buitenland and groote occur 292 times together in window
# 1871 | buitenland and groote occur 254 times together in window
# 1872 | buitenland and groote occur 191 times together in window
# 1873 | buitenland and groote occur 224 times together in window
# 1874 | buitenland and groote occur 223 times together in window
# 1875 | buitenland and groote occur 439 times together in window
# 1876 | buitenland and groote occur 323 times together in window
# 1877 | buitenland and groote occur 251 times together in window
# 1878 | buitenland and groote occur 256 times together in window
# 1879 | buitenland and groote occur 244 times together in window
# 1880 | buitenland and groote occur 251 times together in window
# 1881 | buitenland and groote occur 216 times together in window
# 1882 | buitenland and groote occur 247 times together in window
# 1883 | buitenland and groote occur 259 times together in window
# 1884 | buitenland and groote occur 252 times together in window
# 1885 | buitenland and groote occur 227 times together in window
# 1886 | buitenland and groote occur 259 times together in window
# 1887 | buitenland and groote occur 236 times together in window
# 1888 | buitenland and groote occur 256 times together in window
# 1889 | buitenland and groote occur 264 times together in window
# 1890 | buitenland and groote occur 256 times together in window
# 1891 | buitenland and groote occur 238 times together in window
# 1892 | buitenland and groote occur 257 times together in window
# 1893 | buitenland and groote occur 256 times together in window
# 1894 | buitenland and groote occur 229 times together in window
# 1895 | buitenland and groote occur 277 times together in window
# 1896 | buitenland and groote occur 225 times together in window
# 1897 | buitenland and groote occur 296 times together in window
# 1898 | buitenland and groote occur 297 times together in window
# 1899 | buitenland and groote occur 273 times together in window
# 1900 | buitenland and groote occur 299 times together in window
# 1901 | buitenland and groote occur 248 times together in window
# 1902 | buitenland and groote occur 248 times together in window
# 1903 | buitenland and groote occur 238 times together in window
# 1904 | buitenland and groote occur 255 times together in window
# 1905 | buitenland and groote occur 298 times together in window
# 1906 | buitenland and groote occur 267 times together in window
# 1907 | buitenland and groote occur 231 times together in window
# 1908 | buitenland and groote occur 282 times together in window
# 1909 | buitenland and groote occur 273 times together in window
# 1910 | buitenland and groote occur 222 times together in window
# 1911 | buitenland and groote occur 248 times together in window
# 1912 | buitenland and groote occur 273 times together in window
# 1913 | buitenland and groote occur 239 times together in window
# 1914 | buitenland and groote occur 258 times together in window

# %%
w = df.plot.line(x='year', y='pmi')

# %%
os.chdir("C:\\Users\\Ruben\\Documents\\GitHub\\TheForeign\\Properties\\output-data")

df.to_csv('pmi_buitenlandsche_groote.csv', index = True)
